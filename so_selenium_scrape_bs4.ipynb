# %%
property owner

# %%
html = """<!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" lang="en" jstcache="0"><head><link type="text/css" rel="stylesheet" href="http://fonts.googleapis.com/css?family=Roboto:300,400,500,700" /><style type="text/css">.gm-style .gm-style-cc span,.gm-style .gm-style-cc a,.gm-style .gm-style-mtc div{font-size:10px}
</style><style type="text/css">@media print {  .gm-style .gmnoprint, .gmnoprint {    display:none  }}@media screen {  .gm-style .gmnoscreen, .gmnoscreen {    display:none  }}</style><style type="text/css">.gm-style-pbc{transition:opacity ease-in-out;background-color:rgba(0,0,0,0.45);text-align:center}.gm-style-pbt{font-size:22px;color:white;font-family:Roboto,Arial,sans-serif;position:relative;margin:0;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%)}
</style><script type="text/javascript" src="https://bam.nr-data.net/1/f87bb85d4d?a=53754331&amp;v=1071.385e752&amp;to=ZARVbUBSCkJSAkIMCl1OdmpiHBRQVARFShVBDkdcQEcdHkAUWwgEQRgZWEFDHA%3D%3D&amp;rst=2670&amp;ref=http://www.narrpr.com/homes/tx/san-antonio/78245/723-heritage-way/27795318-summary.aspx&amp;qt=1&amp;ap=472&amp;be=731&amp;fe=2664&amp;dc=1400&amp;af=err,xhr,stn,ins&amp;perf=%7B%22timing%22:%7B%22of%22:1517096509736,%22n%22:0,%22u%22:664,%22ue%22:664,%22f%22:3,%22dn%22:3,%22dne%22:3,%22c%22:3,%22ce%22:3,%22rq%22:4,%22rp%22:658,%22rpe%22:932,%22dl%22:669,%22di%22:1400,%22ds%22:1400,%22de%22:1448,%22dc%22:2664,%22l%22:2664,%22le%22:2665%7D,%22navigation%22:%7B%7D%7D&amp;jsonp=NREUM.setToken"></script><script src="https://js-agent.newrelic.com/nr-1071.min.js"></script><script type="text/javascript" async="" src="http://www.google-analytics.com/plugins/ua/linkid.js"></script>
<!-- Build Version: 1.66.29.2 //-->
<!-- Path/Query: /pages/property/summary.aspx?id=27795318&amp; //-->
<!-- Exec Path: /pages/property/summary.aspx //-->
<title>
Home Details for 723 Heritage Way, San Antonio, TX 78245 (Summary) - Realtors Property Resource
</title><meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><meta http-equiv="X-UA-Compatible" content="IE=Edge" /><script async="" src="//www.google-analytics.com/analytics.js"></script><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"f87bb85d4d","applicationID":"53754331","transactionName":"ZARVbUBSCkJSAkIMCl1OdmpiHBRQVARFShVBDkdcQEcdHkAUWwgEQRgZWEFDHA==","queueTime":1,"applicationTime":472,"agent":"","atts":""}</script><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VQACUldUABAFV1ZXAwIEVw=="};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o&lt;e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&amp;&amp;console.log(t)}catch(n){}}var o,i=t("ee"),a=t(15),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&amp;&amp;"function"==typeof console.log&amp;&amp;(s.console=!0,o.indexOf("dev")!==-1&amp;&amp;(s.dev=!0),o.indexOf("nr_dev")!==-1&amp;&amp;(s.nrDev=!0))}catch(c){}s.nrDev&amp;&amp;i.on("internal-error",function(t){r(t.stack)}),s.dev&amp;&amp;i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&amp;&amp;(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&amp;&amp;u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(16),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&amp;&amp;(t(8),t(7),"addEventListener"in window&amp;&amp;t(5),c.xhrWrappable&amp;&amp;t(9),d=!0)}s.on("fn-start",function(t,n,e){d&amp;&amp;(p+=1)}),s.on("fn-err",function(t,n,e){d&amp;&amp;!e[l]&amp;&amp;(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&amp;&amp;!this.thrown&amp;&amp;p&gt;0&amp;&amp;(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&amp;&amp;window.performance.timing&amp;&amp;window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&amp;&amp;(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&amp;&amp;i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&amp;&amp;(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&amp;&amp;!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&amp;&amp;o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&amp;&amp;(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(18)(r);n.exports=r,o.inPlace(window.history,["pushState","replaceState"],"-")},{}],7:[function(t,n,e){var r=t("ee").get("raf"),o=t(18)(r),i="equestAnimationFrame";n.exports=r,o.inPlace(window,["r"+i,"mozR"+i,"webkitR"+i,"msR"+i],"raf-"),r.on("raf-start",function(t){t[0]=o(t[0],"fn-")})},{}],8:[function(t,n,e){function r(t,n,e){t[0]=a(t[0],"fn-",null,e)}function o(t,n,e){this.method=e,this.timerDuration=isNaN(t[1])?0:+t[1],t[0]=a(t[0],"fn-",this,e)}var i=t("ee").get("timer"),a=t(18)(i),s="setTimeout",c="setInterval",f="clearTimeout",u="-start",d="-";n.exports=i,a.inPlace(window,[s,"setImmediate"],s+d),a.inPlace(window,[c],c+d),a.inPlace(window,[f,"clearImmediate"],f+d),i.on(c+u,r),i.on(s+u,o)},{}],9:[function(t,n,e){function r(t,n){d.inPlace(n,["onreadystatechange"],"fn-",s)}function o(){var t=this,n=u.context(t);t.readyState&gt;3&amp;&amp;!n.resolved&amp;&amp;(n.resolved=!0,u.emit("xhr-resolved",[],t)),d.inPlace(t,y,"fn-",s)}function i(t){g.push(t),h&amp;&amp;(x?x.then(a):w?w(a):(E=-E,O.data=E))}function a(){for(var t=0;t&lt;g.length;t++)r([],g[t]);g.length&amp;&amp;(g=[])}function s(t,n){return n}function c(t,n){for(var e in t)n[e]=t[e];return n}t(5);var f=t("ee"),u=f.get("xhr"),d=t(18)(u),l=NREUM.o,p=l.XHR,h=l.MO,m=l.PR,w=l.SI,v="readystatechange",y=["onload","onerror","onabort","onloadstart","onloadend","onprogress","ontimeout"],g=[];n.exports=u;var b=window.XMLHttpRequest=function(t){var n=new p(t);try{u.emit("new-xhr",[n],n),n.addEventListener(v,o,!1)}catch(e){try{u.emit("internal-error",[e])}catch(r){}}return n};if(c(p,b),b.prototype=p.prototype,d.inPlace(b.prototype,["open","send"],"-xhr-",s),u.on("send-xhr-start",function(t,n){r(t,n),i(n)}),u.on("open-xhr-start",r),h){var x=m&amp;&amp;m.resolve();if(!w&amp;&amp;!m){var E=1,O=document.createTextNode(E);new h(a).observe(O,{characterData:!0})}}else f.on("fn-end",function(t){t[0]&amp;&amp;t[0].type===v||a()})},{}],10:[function(t,n,e){function r(t){var n=this.params,e=this.metrics;if(!this.ended){this.ended=!0;for(var r=0;r&lt;d;r++)t.removeEventListener(u[r],this.listener,!1);if(!n.aborted){if(e.duration=a.now()-this.startTime,4===t.readyState){n.status=t.status;var i=o(t,this.lastSize);if(i&amp;&amp;(e.rxSize=i),this.sameOrigin){var c=t.getResponseHeader("X-NewRelic-App-Data");c&amp;&amp;(n.cat=c.split(", ").pop())}}else n.status=0;e.cbTime=this.cbTime,f.emit("xhr-done",[t],t),s("xhr",[n,e,this.startTime])}}}function o(t,n){var e=t.responseType;if("json"===e&amp;&amp;null!==n)return n;var r="arraybuffer"===e||"blob"===e||"json"===e?t.response:t.responseText;return h(r)}function i(t,n){var e=c(n),r=t.params;r.host=e.hostname+":"+e.port,r.pathname=e.pathname,t.sameOrigin=e.sameOrigin}var a=t("loader");if(a.xhrWrappable){var s=t("handle"),c=t(11),f=t("ee"),u=["load","error","abort","timeout"],d=u.length,l=t("id"),p=t(14),h=t(13),m=window.XMLHttpRequest;a.features.xhr=!0,t(9),f.on("new-xhr",function(t){var n=this;n.totalCbs=0,n.called=0,n.cbTime=0,n.end=r,n.ended=!1,n.xhrGuids={},n.lastSize=null,p&amp;&amp;(p&gt;34||p&lt;10)||window.opera||t.addEventListener("progress",function(t){n.lastSize=t.loaded},!1)}),f.on("open-xhr-start",function(t){this.params={method:t[0]},i(this,t[1]),this.metrics={}}),f.on("open-xhr-end",function(t,n){"loader_config"in NREUM&amp;&amp;"xpid"in NREUM.loader_config&amp;&amp;this.sameOrigin&amp;&amp;n.setRequestHeader("X-NewRelic-ID",NREUM.loader_config.xpid)}),f.on("send-xhr-start",function(t,n){var e=this.metrics,r=t[0],o=this;if(e&amp;&amp;r){var i=h(r);i&amp;&amp;(e.txSize=i)}this.startTime=a.now(),this.listener=function(t){try{"abort"===t.type&amp;&amp;(o.params.aborted=!0),("load"!==t.type||o.called===o.totalCbs&amp;&amp;(o.onloadCalled||"function"!=typeof n.onload))&amp;&amp;o.end(n)}catch(e){try{f.emit("internal-error",[e])}catch(r){}}};for(var s=0;s&lt;d;s++)n.addEventListener(u[s],this.listener,!1)}),f.on("xhr-cb-time",function(t,n,e){this.cbTime+=t,n?this.onloadCalled=!0:this.called+=1,this.called!==this.totalCbs||!this.onloadCalled&amp;&amp;"function"==typeof e.onload||this.end(e)}),f.on("xhr-load-added",function(t,n){var e=""+l(t)+!!n;this.xhrGuids&amp;&amp;!this.xhrGuids[e]&amp;&amp;(this.xhrGuids[e]=!0,this.totalCbs+=1)}),f.on("xhr-load-removed",function(t,n){var e=""+l(t)+!!n;this.xhrGuids&amp;&amp;this.xhrGuids[e]&amp;&amp;(delete this.xhrGuids[e],this.totalCbs-=1)}),f.on("addEventListener-end",function(t,n){n instanceof m&amp;&amp;"load"===t[0]&amp;&amp;f.emit("xhr-load-added",[t[1],t[2]],n)}),f.on("removeEventListener-end",function(t,n){n instanceof m&amp;&amp;"load"===t[0]&amp;&amp;f.emit("xhr-load-removed",[t[1],t[2]],n)}),f.on("fn-start",function(t,n,e){n instanceof m&amp;&amp;("onload"===e&amp;&amp;(this.onload=!0),("load"===(t[0]&amp;&amp;t[0].type)||this.onload)&amp;&amp;(this.xhrCbStart=a.now()))}),f.on("fn-end",function(t,n){this.xhrCbStart&amp;&amp;f.emit("xhr-cb-time",[a.now()-this.xhrCbStart,this.onload,n],n)})}},{}],11:[function(t,n,e){n.exports=function(t){var n=document.createElement("a"),e=window.location,r={};n.href=t,r.port=n.port;var o=n.href.split("://");!r.port&amp;&amp;o[1]&amp;&amp;(r.port=o[1].split("/")[0].split("@").pop().split(":")[1]),r.port&amp;&amp;"0"!==r.port||(r.port="https"===o[0]?"443":"80"),r.hostname=n.hostname||e.hostname,r.pathname=n.pathname,r.protocol=o[0],"/"!==r.pathname.charAt(0)&amp;&amp;(r.pathname="/"+r.pathname);var i=!n.protocol||":"===n.protocol||n.protocol===e.protocol,a=n.hostname===document.domain&amp;&amp;n.port===e.port;return r.sameOrigin=i&amp;&amp;(!n.hostname||a),r}},{}],12:[function(t,n,e){function r(){}function o(t,n,e){return function(){return i(t,[f.now()].concat(s(arguments)),n?null:this,e),n?void 0:this}}var i=t("handle"),a=t(15),s=t(16),c=t("ee").get("tracer"),f=t("loader"),u=NREUM;"undefined"==typeof window.newrelic&amp;&amp;(newrelic=u);var d=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],l="api-",p=l+"ixn-";a(d,function(t,n){u[n]=o(l+n,!0,"api")}),u.addPageAction=o(l+"addPageAction",!0),u.setCurrentRouteName=o(l+"routeName",!0),n.exports=newrelic,u.interaction=function(){return(new r).get()};var h=r.prototype={createTracer:function(t,n){var e={},r=this,o="function"==typeof n;return i(p+"tracer",[f.now(),t,e],r),function(){if(c.emit((o?"":"no-")+"fn-start",[f.now(),r,o],e),o)try{return n.apply(this,arguments)}catch(t){throw c.emit("fn-err",[arguments,this,t],e),t}finally{c.emit("fn-end",[f.now()],e)}}}};a("setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,n){h[n]=o(p+n)}),newrelic.noticeError=function(t){"string"==typeof t&amp;&amp;(t=new Error(t)),i("err",[t,f.now()])}},{}],13:[function(t,n,e){n.exports=function(t){if("string"==typeof t&amp;&amp;t.length)return t.length;if("object"==typeof t){if("undefined"!=typeof ArrayBuffer&amp;&amp;t instanceof ArrayBuffer&amp;&amp;t.byteLength)return t.byteLength;if("undefined"!=typeof Blob&amp;&amp;t instanceof Blob&amp;&amp;t.size)return t.size;if(!("undefined"!=typeof FormData&amp;&amp;t instanceof FormData))try{return JSON.stringify(t).length}catch(n){return}}}},{}],14:[function(t,n,e){var r=0,o=navigator.userAgent.match(/Firefox[\/\s](\d+\.\d+)/);o&amp;&amp;(r=+o[1]),n.exports=r},{}],15:[function(t,n,e){function r(t,n){var e=[],r="",i=0;for(r in t)o.call(t,r)&amp;&amp;(e[i]=n(r,t[r]),i+=1);return e}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],16:[function(t,n,e){function r(t,n,e){n||(n=0),"undefined"==typeof e&amp;&amp;(e=t?t.length:0);for(var r=-1,o=e-n||0,i=Array(o&lt;0?0:o);++r&lt;o;)i[r]=t[n+r];return i}n.exports=r},{}],17:[function(t,n,e){n.exports={exists:"undefined"!=typeof window.performance&amp;&amp;window.performance.timing&amp;&amp;"undefined"!=typeof window.performance.timing.navigationStart}},{}],18:[function(t,n,e){function r(t){return!(t&amp;&amp;t instanceof Function&amp;&amp;t.apply&amp;&amp;!t[a])}var o=t("ee"),i=t(16),a="nr@original",s=Object.prototype.hasOwnProperty,c=!1;n.exports=function(t,n){function e(t,n,e,o){function nrWrapper(){var r,a,s,c;try{a=this,r=i(arguments),s="function"==typeof e?e(r,a):e||{}}catch(f){l([f,"",[r,a,o],s])}u(n+"start",[r,a,o],s);try{return c=t.apply(a,r)}catch(d){throw u(n+"err",[r,a,d],s),d}finally{u(n+"end",[r,a,c],s)}}return r(t)?t:(n||(n=""),nrWrapper[a]=t,d(t,nrWrapper),nrWrapper)}function f(t,n,o,i){o||(o="");var a,s,c,f="-"===o.charAt(0);for(c=0;c&lt;n.length;c++)s=n[c],a=t[s],r(a)||(t[s]=e(a,f?s+o:o,i,s))}function u(e,r,o){if(!c||n){var i=c;c=!0;try{t.emit(e,r,o,n)}catch(a){l([a,e,r,o])}c=i}}function d(t,n){if(Object.defineProperty&amp;&amp;Object.keys)try{var e=Object.keys(t);return e.forEach(function(e){Object.defineProperty(n,e,{get:function(){return t[e]},set:function(n){return t[e]=n,n}})}),n}catch(r){l([r])}for(var o in t)s.call(t,o)&amp;&amp;(n[o]=t[o]);return n}function l(n){try{t.emit("internal-error",n)}catch(e){}}return t||(t=o),e.inPlace=f,e.flag=a,e}},{}],ee:[function(t,n,e){function r(){}function o(t){function n(t){return t&amp;&amp;t instanceof r?t:t?c(t,s,i):i()}function e(e,r,o,i){if(!l.aborted||i){t&amp;&amp;t(e,r,o);for(var a=n(o),s=h(e),c=s.length,f=0;f&lt;c;f++)s[f].apply(a,r);var d=u[y[e]];return d&amp;&amp;d.push([g,e,r,a]),a}}function p(t,n){v[t]=h(t).concat(n)}function h(t){return v[t]||[]}function m(t){return d[t]=d[t]||o(e)}function w(t,n){f(t,function(t,e){n=n||"feature",y[e]=n,n in u||(u[n]=[])})}var v={},y={},g={on:p,emit:e,get:m,listeners:h,context:n,buffer:w,abort:a,aborted:!1};return g}function i(){return new r}function a(){(u.api||u.feature)&amp;&amp;(l.aborted=!0,u=l.backlog={})}var s="nr@context",c=t("gos"),f=t(15),u={},d={},l=n.exports=o();l.backlog=u},{}],gos:[function(t,n,e){function r(t,n,e){if(o.call(t,n))return t[n];var r=e();if(Object.defineProperty&amp;&amp;Object.keys)try{return Object.defineProperty(t,n,{value:r,writable:!0,enumerable:!1}),r}catch(i){}return t[n]=r,r}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],handle:[function(t,n,e){function r(t,n,e,r){o.buffer([t],r),o.emit(t,n,e)}var o=t("ee").get("handle");n.exports=r,r.ee=o},{}],id:[function(t,n,e){function r(t){var n=typeof t;return!t||"object"!==n&amp;&amp;"function"!==n?-1:t===window?0:a(t,i,function(){return o++})}var o=1,i="nr@id",a=t("gos");n.exports=r},{}],loader:[function(t,n,e){function r(){if(!x++){var t=b.info=NREUM.info,n=l.getElementsByTagName("script")[0];if(setTimeout(u.abort,3e4),!(t&amp;&amp;t.licenseKey&amp;&amp;t.applicationID&amp;&amp;n))return u.abort();f(y,function(n,e){t[n]||(t[n]=e)}),c("mark",["onload",a()+b.offset],null,"api");var e=l.createElement("script");e.src="https://"+t.agent,n.parentNode.insertBefore(e,n)}}function o(){"complete"===l.readyState&amp;&amp;i()}function i(){c("mark",["domContent",a()+b.offset],null,"api")}function a(){return E.exists&amp;&amp;performance.now?Math.round(performance.now()):(s=Math.max((new Date).getTime(),s))-b.offset}var s=(new Date).getTime(),c=t("handle"),f=t(15),u=t("ee"),d=window,l=d.document,p="addEventListener",h="attachEvent",m=d.XMLHttpRequest,w=m&amp;&amp;m.prototype;NREUM.o={ST:setTimeout,SI:d.setImmediate,CT:clearTimeout,XHR:m,REQ:d.Request,EV:d.Event,PR:d.Promise,MO:d.MutationObserver};var v=""+location,y={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",agent:"js-agent.newrelic.com/nr-1071.min.js"},g=m&amp;&amp;w&amp;&amp;w[p]&amp;&amp;!/CriOS/.test(navigator.userAgent),b=n.exports={offset:s,now:a,origin:v,features:{},xhrWrappable:g};t(12),l[p]?(l[p]("DOMContentLoaded",i,!1),d[p]("load",r,!1)):(l[h]("onreadystatechange",o),d[h]("onload",r)),c("mark",["firstbyte",s],null,"api");var x=0,E=t(17)},{}]},{},["loader",2,10,4,3]);</script>
<meta name="author" content="Realtors Property Resource®" />
<meta name="copyright" content="Copyright © 2018 Realtors Property Resource®" />
<meta name="viewport" content="width=device-width" />
<meta name="apple-itunes-app" content="app-id=900143341, app-argument=http://www.narrpr.com/find/?action=propertydetails&amp;query=723%20Heritage%20Way%2c%20San%20Antonio%2c%20TX%2078245" />
<meta name="google-play-app" content="app-id=com.rpr.mobile" />
<link rel="apple-touch-icon" href="http://static.narrpr.com/1.66.29.2/images/misc/apple-touch-icon.png" />
<link rel="SHORTCUT ICON" href="/favicon.ico" /><link href="/resources/1.66.29.2/style.ashx/common" type="text/css" rel="stylesheet" />
<link href="/resources/1.66.29.2/style.ashx/propertyPages" type="text/css" rel="stylesheet" />
<style type="text/css">
.coBrand .siteHeader .topLogo.coBrandLogo { background-image:url(http://staticaws.narrpr.com/Images/Orgs/TXSABOR-n/CoBrand.TXSABOR-n.Logo.Header.2011-04-22-19-38-48.png); } .coBrand.mini-logo .siteHeader .topLogo.coBrandLogo { background-image:url(http://staticaws.narrpr.com/Images/Orgs/TXSABOR-n/CoBrand.TXSABOR-n.Logo.Footer.2011-04-22-19-38-48.png); }
</style>
<script type="text/javascript">
if (!window.console || !window.console.log) { window.console = { log : function () {  } }; }
function errorHandler(desc, page, line, chr) { console.log("ERROR: " + desc + "; " + page + "; Line " + line); return true; }
window.onerror = errorHandler;
</script>
<script type="text/javascript" src="//ajax.googleapis.com/ajax/libs/jquery/1.12.0/jquery.min.js"></script>
<meta name="description" content="723 Heritage Way, San Antonio, TX 78245 Find house value estimates for home or a prospective home at narrpr.com." /><meta name="keywords" content="723 Heritage Way San Antonio TX 78245, house values estimates, free house values, home value estimate, home value estimator, house value, property values, house prices, home values, home prices, property calculator, property info, property details, worth, price" /><script type="text/javascript" charset="UTF-8" src="http://maps.googleapis.com/maps-api-v3/api/js/30/13/common.js"></script><script type="text/javascript" charset="UTF-8" src="http://maps.googleapis.com/maps-api-v3/api/js/30/13/map.js"></script><script type="text/javascript" language="JavaScript" src="http://dc1.parcelstream.com/_T193/InitSession.aspx?sik=_T193/61197ec1-abd8-4ecd-9847-36c58c6d6d8a_M&amp;obsId=window&amp;obsSuccessMethod=S151709651135117952122011&amp;obsErrorMethod=E151709651135117952122011&amp;output=json"></script><script type="text/javascript" charset="UTF-8" src="http://maps.googleapis.com/maps-api-v3/api/js/30/13/util.js"></script><script type="text/javascript" charset="UTF-8" src="http://maps.googleapis.com/maps-api-v3/api/js/30/13/streetview.js"></script><style type="text/css">.gm-style {
        font: 400 11px Roboto, Arial, sans-serif;
        text-decoration: none;
      }
      .gm-style img { max-width: none; }</style><script type="text/javascript" charset="UTF-8" src="http://maps.googleapis.com/maps-api-v3/api/js/30/13/onion.js"></script><script type="text/javascript" charset="UTF-8" src="http://maps.googleapis.com/maps/api/js/ViewportInfoService.GetViewportInfo?1m6&amp;1m2&amp;1d29.433388236273544&amp;2d-98.68657451935576&amp;2m2&amp;1d29.437356570130188&amp;2d-98.68196613165128&amp;2u18&amp;4sen-US&amp;5e0&amp;6sm%40409000000&amp;7b0&amp;8e0&amp;callback=_xdc_._th8mjn&amp;token=8942"></script><script type="text/javascript" charset="UTF-8" src="http://maps.googleapis.com/maps-api-v3/api/js/30/13/controls.js"></script><script type="text/javascript" charset="UTF-8" src="http://maps.googleapis.com/maps-api-v3/api/js/30/13/marker.js"></script><script type="text/javascript" charset="UTF-8" src="https://maps.googleapis.com/maps/api/js/GeoPhotoService.SingleImageSearch?pb=!1m5!1sapiv3!5sUS!11m2!1m1!1b0!2m4!1m2!3d29.435427!4d-98.68424600000003!2d35!3m20!1m1!3b1!2m2!1sen!2sUS!9m1!1e1!11m12!1m3!1e2!2b1!3e2!1m3!1e3!2b1!3e2!1m3!1e10!2b1!3e2!4m6!1e1!1e2!1e3!1e4!1e8!1e6&amp;callback=_xdc_._6n7ljd"></script><script type="text/javascript" language="JavaScript" src="http://parcelstream.com/UserProperties.aspx?&amp;obsId=window&amp;obsSuccessMethod=S151709651154018967787902&amp;obsErrorMethod=E151709651154018967787902&amp;output=json"></script><script type="text/javascript" charset="UTF-8" src="http://maps.googleapis.com/maps-api-v3/api/js/30/13/imagery_viewer.js"></script><style>.gm-iv-container{width:27px;margin-top:10px;border-right:1px solid #666;background-color:#222222;opacity:0.8;font-family:Roboto,Arial}.gm-iv-small-container{height:56px}.gm-iv-large-container{height:72px;padding-top:14px}.gm-iv-close{width:27px;height:27px;margin-top:13px;outline-color:#000;display:inline-block}.gm-iv-back{display:inline-block;height:15px;width:15px;padding:6px}.gm-iv-back-icon{cursor:pointer;overflow:hidden;width:15px;height:15px;position:absolute;background-position:-3px -70px}.gm-iv-back-icon:hover{background-position:-40px -70px}.gm-iv-back-icon-background{background-image:url(https://maps.gstatic.com/mapfiles/api-3/images/sv9.png);background-size:164px 175px}.gm-iv-back-icon-rtl{cursor:pointer;overflow:hidden;width:15px;height:15px;position:absolute;background-position:28px -70px}.gm-iv-back-icon-rtl:hover{background-position:65px -70px}@media (-webkit-min-device-pixel-ratio:1.2),(min-resolution:1.2dppx),(min-resolution:116dpi){.gm-iv-back-icon-background{background-image:url(https://maps.gstatic.com/mapfiles/api-3/images/sv9_hdpi.png)}}</style><script type="text/javascript" charset="UTF-8" src="http://maps.googleapis.com/maps-api-v3/api/js/30/13/geocoder.js"></script><script type="text/javascript" charset="UTF-8" src="http://maps.googleapis.com/maps-api-v3/api/js/30/13/usage.js"></script><style>.gm-style .gm-compass-icon{background-image:url(https://maps.gstatic.com/mapfiles/api-3/images/sv9.png);background-size:164px 175px}.gm-style.gm-china .gm-compass-icon{background-image:url(http://maps.gstatic.cn/mapfiles/api-3/images/sv9.png)}@media (-webkit-min-device-pixel-ratio:1.2),(min-resolution:1.2dppx),(min-resolution:116dpi){.gm-style .gm-compass-icon{background-image:url(https://maps.gstatic.com/mapfiles/api-3/images/sv9_hdpi.png)}.gm-style.gm-china .gm-compass-icon{background-image:url(http://maps.gstatic.cn/mapfiles/api-3/images/sv9_hdpi.png)}}.gm-compass-background{height:48px;width:48px;overflow:hidden;position:absolute}.gm-compass{position:relative;width:48px;height:48px}.gm-compass-needle{cursor:pointer;overflow:hidden;width:20px;height:39px;position:absolute;left:14.5px;top:4px}.gm-compass-needle{background-position:110px -5.5px}.gm-compass-needle:hover{background-position:88px -5.5px}.gm-compass-needle:active{background-position:66px -5.5px}.gm-compass-turn{cursor:pointer;overflow:hidden;width:12px;height:35px;position:absolute;left:2px;top:8px}.gm-compass-turn{background-position:46px -8px}.gm-compass-turn:hover{background-position:30px -8px}.gm-compass-turn:active{background-position:14px -8px}.gm-compass-turn-opposite{-ms-transform:scaleX(-1);-ms-transform-origin:22.5px 0;-moz-transform:scaleX(-1);-moz-transform-origin:22.5px 0;-webkit-transform:scaleX(-1);-webkit-transform-origin:22.5px 0;transform:scaleX(-1);transform-origin:22.5px 0}.gm-compass:hover .gm-compass-tooltip-text,.gm-compass:hover .gm-compass-arrow-right{opacity:1;-webkit-transition-delay:1.5s;-moz-transition-delay:1.5s;transition-delay:1.5s}.gm-compass-tooltip-text{opacity:0;background-color:#222;width:112px;height:23px;right:58px;top:7px;position:absolute;border:1px solid #ccc;text-align:center;color:#ccc;padding-top:7px;font-family:Roboto,Arial;font-size:12px;font-weight:bold}.gm-compass-arrow-right{opacity:0;width:0;height:0;border-top:7px solid transparent;border-bottom:7px solid transparent;top:16px;position:absolute}.gm-compass-arrow-right-outer{right:52px;border-left:7px solid #ccc}.gm-compass-arrow-right-inner{right:53px;border-left:7px solid #222}</style><script type="text/javascript" charset="UTF-8" src="https://maps.googleapis.com/maps/api/js/GeoPhotoService.GetMetadata?pb=!1m5!1sapiv3!5sUS!11m2!1m1!1b0!2m2!1sen!2sUS!3m3!1m2!1e2!2sCuftsMK5Hz2LP8GjDOTShg!4m6!1e1!1e2!1e3!1e4!1e8!1e6&amp;callback=_xdc_._prm62x"></script><style>.gm-iv-address{background-color:#222222;opacity:0.8;font-family:Roboto,Arial;outline-color:#000;border-bottom-right-radius:2px;border-top-right-radius:2px;display:inline-block;padding:6px 8px;margin-top:10px;height:44px}.gm-iv-address-large{height:74px}.gm-iv-address-description{display:inline-block;min-width:107px;max-width:310px;vertical-align:top;position:relative;height:44px;padding-right:30px}.gm-iv-short-address-description{color:#fff;font-weight:bold;font-size:12px;overflow:hidden;white-space:nowrap;text-overflow:ellipsis;padding-bottom:2px}.gm-iv-long-address-description{color:#ccc;font-weight:normal;font-size:11px;overflow:hidden;white-space:nowrap;text-overflow:ellipsis;min-width:70px}.gm-iv-vertical-separator{height:56px;display:inline-block;width:1px;top:10px;right:28px;position:absolute;background:-webkit-linear-gradient(top,#404040,#666,#404040);background:-moz-linear-gradient(top,#404040,#666,#404040);background:-ms-linear-gradient(top,#404040,#666,#404040);background:-linear-gradient(top,#404040,#666,#404040)}.gm-iv-marker{display:inline-block;height:25px;width:13px;right:8px;position:absolute;top:28px}.gm-iv-marker-icon-background{background-image:url(https://maps.gstatic.com/mapfiles/api-3/images/sv9.png);background-size:164px 175px}.gm-iv-marker-icon{overflow:hidden;width:13px;height:21px;position:absolute;background-position:-17px -50px}.gm-iv-marker-icon:hover{background-position:-1px -50px}.gm-iv-horizontal-separator{height:1px;margin-left:-8px;margin-right:-8px;margin-bottom:6px;background:-webkit-linear-gradient(left,#404040,#666,#404040);background:-moz-linear-gradient(left,#404040,#666,#404040);background:-ms-linear-gradient(left,#404040,#666,#404040);background:-linear-gradient(left,#404040,#666,#404040)}.gm-iv-address-link{position:absolute;top:48px}.gm-iv-address-custom p{color:#777;text-decoration:none;font-size:11px}.gm-iv-address-link a{color:#5c8dcc;text-decoration:none;font-size:11px}.gm-iv-address-link a:hover{text-decoration:underline}.gm-iv-profile-link{color:#fff;font-weight:bold;font-size:12px;overflow:hidden;white-space:nowrap;text-overflow:ellipsis}.gm-iv-profile-url a&gt;.iv-profile-link:hover{text-decoration:underline}.gm-iv-profile-url a{text-decoration:none}.gm-iv-timeline{min-width:100px;max-width:310px;color:#ccc;font-weight:normal;font-size:11px;overflow:hidden;white-space:nowrap;text-overflow:ellipsis;margin-top:6px;margin-right:-8px;margin-left:-8px;padding-right:8px;padding-left:8px}.gm-iv-timeline-description{display:inline-block;margin-top:2px;vertical-align:top}.gm-iv-timeline-description-details{float:left}.gm-iv-timeline-description-separator{padding:0px 2px;float:left}.gm-iv-timeline-wrapper:hover .gm-iv-timeline-description{color:white}.gm-iv-timeline-icon-wrapper{display:inline-block;height:15px;width:26px}.gm-iv-timeline-icon-background{background-image:url(https://maps.gstatic.com/mapfiles/api-3/images/sv9.png);background-size:164px 175px}@media (-webkit-min-device-pixel-ratio:1.2),(min-resolution:1.2dppx),(min-resolution:116dpi){.gm-iv-timeline-icon-background{background-image:url(https://maps.gstatic.com/mapfiles/api-3/images/sv9_hdpi.png)}.gm-iv-marker-icon-background{background-image:url(https://maps.gstatic.com/mapfiles/api-3/images/sv9_hdpi.png)}}.gm-iv-timeline-icon{background-position:-37px -50px;overflow:hidden;width:26px;height:15px;position:absolute}.gm-iv-timeline-wrapper:hover .gm-iv-timeline-icon{background-position:-65px -50px}</style><script type="text/javascript" charset="UTF-8" src="http://maps.googleapis.com/maps/api/js/AuthenticationService.Authenticate?1shttp%3A%2F%2Fwww.narrpr.com%2Fhomes%2Ftx%2Fsan-antonio%2F78245%2F723-heritage-way%2F27795318-summary.aspx&amp;2sgme-realtorsproperty&amp;callback=_xdc_._2mz8ih&amp;token=53594"></script><style>.widget-scene{width:100%;height:100%;overflow:hidden;position:absolute;z-index:0;background-color:black}.keynav-mode .widget-scene:focus::after{content:'';border:2px solid #4d90fe;box-sizing:border-box;height:100%;pointer-events:none;position:absolute;width:100%;z-index:1}.print-mode .widget-scene:focus::after{display:none}.widget-scene-effects{position:absolute;left:0;top:0;z-index:2}.widget-scene-imagery-render{position:absolute;left:0;top:0;z-index:1;background-color:black}.widget-scene-imagery-iframe{position:absolute}.widget-scene .canvas-renderer{position:absolute;left:0;top:0}.widget-scene-canvas{position:absolute;left:0;top:0;background-color:black}.widget-scene-capture-canvas{position:relative;z-index:3}.tile-image-3d{-webkit-perspective:1000;-webkit-backface-visibility:hidden;perspective:1000;backface-visibility:hidden;-moz-perspective:1000;-moz-backface-visibility:hidden;-o-perspective:1000;-o-backface-visibility:hidden}.accelerated{-webkit-transform:translateZ(0);transform:translateZ(0)}@media print{.widget-scene{background:white;position:static;overflow:visible}.widget-scene-canvas{display:block;background:white}.app-globe-mode .widget-scene-canvas{background:black}.widget-scene-imagery-render{position:relative;background:white;z-index:4}.widget-scene-imagery-iframe{position:relative;left:50% !important;transform:translateX(-50%);-webkit-transform:translateX(-50%)}.widget-scene .canvas-renderer,.widget-scene .canvas-container,.widget-scene canvas{position:static !important}.canvas-renderer+.widget-scene-canvas{display:none !important}.widget-scene-capture-canvas+.widget-scene-canvas,.widget-scene-capture-canvas+.canvas-renderer{display:none !important}.widget-scene-canvas{width:100% !important;height:auto !important;-webkit-transform:none !important;transform:none !important}}.print-mode .widget-scene{background:white;position:static;overflow:visible}.print-mode .widget-scene-canvas{display:block;background:white}.print-mode .app-globe-mode .widget-scene-canvas{background:black}.print-mode .widget-scene-imagery-render{position:relative;background:white;z-index:4}.print-mode .widget-scene-imagery-iframe{position:relative;left:50% !important;transform:translateX(-50%);-webkit-transform:translateX(-50%)}.print-mode .widget-scene .canvas-renderer,.print-mode .widget-scene .canvas-container,.print-mode .widget-scene canvas{position:static !important}.print-mode .canvas-renderer+.widget-scene-canvas{display:none !important}.print-mode .widget-scene-capture-canvas+.widget-scene-canvas,.print-mode .widget-scene-capture-canvas+.canvas-renderer{display:none !important}</style><link href="/resources/1.66.29.2/style.ashx/dialogs" rel="Stylesheet" type="text/css" /><script type="text/javascript" src="/resources/1.66.29.2/script.ashx/baseDialog"></script><script type="text/javascript" charset="UTF-8" src="http://maps.googleapis.com/maps-api-v3/api/js/30/13/stats.js"></script><script type="text/javascript" charset="UTF-8" src="http://maps.googleapis.com/maps/api/js/QuotaService.RecordEvent?1shttp%3A%2F%2Fwww.narrpr.com%2Fhomes%2Ftx%2Fsan-antonio%2F78245%2F723-heritage-way%2F27795318-summary.aspx&amp;2sgme-realtorsproperty&amp;7sy03g4n&amp;callback=_xdc_._34sznm&amp;token=47322"></script><script type="text/javascript" charset="UTF-8" src="http://maps.googleapis.com/maps/api/js/StatsService.RecordStats?1m3&amp;1sut%7Cclient%3Agme-realtorsproperty&amp;2sstreetviewStart&amp;5v1&amp;callback=_xdc_._3g7q&amp;token=3603"></script><script type="text/javascript" charset="UTF-8" src="http://maps.googleapis.com/maps/api/js/QuotaService.RecordEvent?1shttp%3A%2F%2Fwww.narrpr.com%2Fhomes%2Ftx%2Fsan-antonio%2F78245%2F723-heritage-way%2F27795318-summary.aspx&amp;2sgme-realtorsproperty&amp;7sy03g9f&amp;callback=_xdc_._34t6bj&amp;token=26401"></script><script type="text/javascript" charset="UTF-8" src="http://maps.googleapis.com/maps/api/js/StatsService.RecordStats?1m3&amp;1sut%7Cclient%3Agme-realtorsproperty&amp;2smapview&amp;5v1&amp;callback=_xdc_._3g9h&amp;token=22469"></script></head>
<body class="rpr coBrand coBrand2" jstcache="0">
<script type="text/javascript">
$(document).ready(function () { $shared.initialize(); });
</script>
<div class="siteContainer" jstcache="0">
<script type="text/javascript">
$(document).ready(function () { Rpr.SiteHeader.Instance = new Rpr.SiteHeader(); });
</script>
<div class="siteHeader">
<div class="siteHeaderOuter">
<div class="siteHeaderInner siteSection">
<script type="text/javascript">
$(document).ready(function ()
{
Rpr.ReportNotification.Instance = new Rpr.ReportNotification({"reportsHistoryPollInterval":60000,"reportTypeLookups":[{"Lookup":{"ReportType":1,"ReportMode":1,"ReportCategory":1,"Name":"Property Report","Description":"The Property Report is a comprehensive look at an individual property, including detailed property information, historical listing photos, local market statistics, listing activity, foreclosure activity, neighborhood demographics and more.","Abbreviation":"P","SamplePageCount":33,"PageZoom":"0.863","PageMarginTop":".9in","PageMarginBottom":".6in","PageMarginLeft":".30in","PageMarginRight":".30in","HtmlColor":"124873","SortOrder":1,"HasBodyContent":true,"AddressCategories":[1],"Products":[1,2],"CommandMethods":[{"CommandMethodType":1,"Parameters":null},{"CommandMethodType":24,"Parameters":null},{"CommandMethodType":33,"Parameters":null},{"CommandMethodType":35,"Parameters":null},{"CommandMethodType":36,"Parameters":null}],"IsAvailableForProperty":true,"IsAvailableForPlace":false,"IsAvailableForSchool":false},"AutoSuggestValidAddressTypes":[8,26,27,28,12,14,17,9],"AutoSuggestValidSearchAreaTypes":[]},{"Lookup":{"ReportType":21,"ReportMode":1,"ReportCategory":1,"Name":"Seller\u0027s Proceeds Form","Description":"","Abbreviation":"Sp","SamplePageCount":2,"PageZoom":"0.863","PageMarginTop":".9in","PageMarginBottom":".6in","PageMarginLeft":".30in","PageMarginRight":".30in","HtmlColor":null,"SortOrder":1,"HasBodyContent":true,"AddressCategories":[1],"Products":[],"CommandMethods":[],"IsAvailableForProperty":true,"IsAvailableForPlace":false,"IsAvailableForSchool":false},"AutoSuggestValidAddressTypes":[8,26,27,28,12,14,17,9],"AutoSuggestValidSearchAreaTypes":[]},{"Lookup":{"ReportType":3,"ReportMode":1,"ReportCategory":1,"Name":"Seller\u0027s Report","Description":"The Seller\u0027s Report is a tool for listing presentations. It reviews the subject property, shows the condition of the local market, presents comparable properties for side-by-side comparison, recommends a pricing strategy and shows estimated seller proceeds.","Abbreviation":"S","SamplePageCount":75,"PageZoom":"0.863","PageMarginTop":".9in","PageMarginBottom":".6in","PageMarginLeft":".30in","PageMarginRight":".30in","HtmlColor":"8FBCDF","SortOrder":2,"HasBodyContent":true,"AddressCategories":[1],"Products":[1,2],"CommandMethods":[{"CommandMethodType":1,"Parameters":null},{"CommandMethodType":24,"Parameters":null},{"CommandMethodType":33,"Parameters":null},{"CommandMethodType":35,"Parameters":null},{"CommandMethodType":36,"Parameters":null}],"IsAvailableForProperty":true,"IsAvailableForPlace":false,"IsAvailableForSchool":false},"AutoSuggestValidAddressTypes":[8,26,27,28,12,14,17,9],"AutoSuggestValidSearchAreaTypes":[]},{"Lookup":{"ReportType":7,"ReportMode":1,"ReportCategory":1,"Name":"Property Flyer","Description":"The Property Flyer is a marketing piece for an individual property featuring a photo selected by the user, property information, a description supplied by the user or from our system, a locator map, and the user\u0027s contact information and branding.","Abbreviation":"Fl","SamplePageCount":1,"PageZoom":"0.915","PageMarginTop":".0in","PageMarginBottom":".0in","PageMarginLeft":".0in","PageMarginRight":".0in","HtmlColor":"777E84","SortOrder":3,"HasBodyContent":false,"AddressCategories":[1],"Products":[1,2],"CommandMethods":[{"CommandMethodType":1,"Parameters":null},{"CommandMethodType":2,"Parameters":null},{"CommandMethodType":7,"Parameters":null},{"CommandMethodType":15,"Parameters":null},{"CommandMethodType":36,"Parameters":null}],"IsAvailableForProperty":true,"IsAvailableForPlace":false,"IsAvailableForSchool":false},"AutoSuggestValidAddressTypes":[8,26,27,28,12,14,17,9],"AutoSuggestValidSearchAreaTypes":[]},{"Lookup":{"ReportType":4,"ReportMode":1,"ReportCategory":1,"Name":"Mini Property Report","Description":"The Mini Property Report provides essential information about a home, much like what is shown on the Summary tab of a Property Details page. The report includes the property\u0027s estimated value; home facts like bedrooms, baths and square footage; and photos.","Abbreviation":"M","SamplePageCount":11,"PageZoom":"0.863","PageMarginTop":".9in","PageMarginBottom":".6in","PageMarginLeft":".30in","PageMarginRight":".30in","HtmlColor":"1E79BF","SortOrder":4,"HasBodyContent":true,"AddressCategories":[1],"Products":[1,2],"CommandMethods":[{"CommandMethodType":1,"Parameters":null},{"CommandMethodType":24,"Parameters":null},{"CommandMethodType":33,"Parameters":null},{"CommandMethodType":35,"Parameters":null},{"CommandMethodType":36,"Parameters":null}],"IsAvailableForProperty":true,"IsAvailableForPlace":false,"IsAvailableForSchool":false},"AutoSuggestValidAddressTypes":[8,26,27,28,12,14,17,9],"AutoSuggestValidSearchAreaTypes":[]},{"Lookup":{"ReportType":12,"ReportMode":1,"ReportCategory":1,"Name":"Valuation Workbook","Description":"The Valuation Workbook summarizes the evaluation made using the Sales Comparison Analysis. It includes details about the subject property and the comps and adjustments made in the workflow, as well as an overview of local housing market conditions.","Abbreviation":"V","SamplePageCount":37,"PageZoom":"0.863","PageMarginTop":".9in","PageMarginBottom":".6in","PageMarginLeft":".30in","PageMarginRight":".30in","HtmlColor":"AA8D4B","SortOrder":5,"HasBodyContent":true,"AddressCategories":[1],"Products":[1],"CommandMethods":[{"CommandMethodType":1,"Parameters":null},{"CommandMethodType":24,"Parameters":null},{"CommandMethodType":33,"Parameters":null},{"CommandMethodType":35,"Parameters":null},{"CommandMethodType":36,"Parameters":null}],"IsAvailableForProperty":true,"IsAvailableForPlace":false,"IsAvailableForSchool":false},"AutoSuggestValidAddressTypes":[8,26,27,28,12,14,17,9],"AutoSuggestValidSearchAreaTypes":[]},{"Lookup":{"ReportType":2,"ReportMode":1,"ReportCategory":1,"Name":"Market Activity Report","Description":"The Market Activity Report is a snapshot of all the changes in a local real estate market. It includes a market activity summary and a listing of active, pending, sold, expired and distressed properties. Recent price changes and upcoming open houses are also included.","Abbreviation":"A","SamplePageCount":11,"PageZoom":"0.863","PageMarginTop":".9in","PageMarginBottom":".6in","PageMarginLeft":".30in","PageMarginRight":".30in","HtmlColor":"D2E4E2","SortOrder":6,"HasBodyContent":true,"AddressCategories":[1,2],"Products":[1,2],"CommandMethods":[{"CommandMethodType":24,"Parameters":null},{"CommandMethodType":35,"Parameters":null},{"CommandMethodType":36,"Parameters":null}],"IsAvailableForProperty":true,"IsAvailableForPlace":true,"IsAvailableForSchool":false},"AutoSuggestValidAddressTypes":[8,26,27,28,12,14,17,9,5,6,32,33,34,35,13,15,16],"AutoSuggestValidSearchAreaTypes":null},{"Lookup":{"ReportType":5,"ReportMode":1,"ReportCategory":1,"Name":"Neighborhood Report","Description":"The Neighborhood Report summarizes economic, housing, demographic and quality of life information about an area.","Abbreviation":"N","SamplePageCount":10,"PageZoom":"0.863","PageMarginTop":".9in","PageMarginBottom":".6in","PageMarginLeft":".30in","PageMarginRight":".30in","HtmlColor":"DAC597","SortOrder":7,"HasBodyContent":true,"AddressCategories":[1,2],"Products":[1,2],"CommandMethods":[{"CommandMethodType":24,"Parameters":null},{"CommandMethodType":35,"Parameters":null},{"CommandMethodType":36,"Parameters":null}],"IsAvailableForProperty":true,"IsAvailableForPlace":true,"IsAvailableForSchool":false},"AutoSuggestValidAddressTypes":[8,26,27,28,12,14,17,9,5,6,32,33,34,35,13],"AutoSuggestValidSearchAreaTypes":[]},{"Lookup":{"ReportType":6,"ReportMode":1,"ReportCategory":1,"Name":"School Report","Description":"The School Report summarizes student population, testing outcomes and community information about a public or private school.","Abbreviation":"Sc","SamplePageCount":6,"PageZoom":"0.863","PageMarginTop":".9in","PageMarginBottom":".6in","PageMarginLeft":".30in","PageMarginRight":".30in","HtmlColor":"FAB700","SortOrder":8,"HasBodyContent":true,"AddressCategories":[3],"Products":[1,2],"CommandMethods":[{"CommandMethodType":24,"Parameters":null},{"CommandMethodType":35,"Parameters":null},{"CommandMethodType":36,"Parameters":null}],"IsAvailableForProperty":false,"IsAvailableForPlace":false,"IsAvailableForSchool":true},"AutoSuggestValidAddressTypes":[],"AutoSuggestValidSearchAreaTypes":[]},{"Lookup":{"ReportType":16,"ReportMode":1,"ReportCategory":2,"Name":"Federal Economic Area Report","Description":"The Federal Economic Area Report summarizes the demographics, consumer behavior and economic trends in an area. The report can be generated for a congressional district or a state.","Abbreviation":"F","SamplePageCount":9,"PageZoom":"0.863","PageMarginTop":".9in","PageMarginBottom":".6in","PageMarginLeft":".30in","PageMarginRight":".30in","HtmlColor":"000000","SortOrder":11,"HasBodyContent":true,"AddressCategories":[2],"Products":[1],"CommandMethods":[],"IsAvailableForProperty":false,"IsAvailableForPlace":true,"IsAvailableForSchool":false},"AutoSuggestValidAddressTypes":[5,6,32,33,34,35,13],"AutoSuggestValidSearchAreaTypes":[]},{"Lookup":{"ReportType":15,"ReportMode":1,"ReportCategory":2,"Name":"Local Economic Area Report","Description":"The Local Economic Area Report summarizes the demographics, consumer behavior and economic trends in an area. The report can be generated for a county, city, ZIP code, neighborhood or minor civil division (such as a township, village or other district), or a custom area.","Abbreviation":"L","SamplePageCount":9,"PageZoom":"0.863","PageMarginTop":".9in","PageMarginBottom":".6in","PageMarginLeft":".30in","PageMarginRight":".30in","HtmlColor":"000000","SortOrder":12,"HasBodyContent":true,"AddressCategories":[2],"Products":[1],"CommandMethods":[],"IsAvailableForProperty":false,"IsAvailableForPlace":true,"IsAvailableForSchool":false},"AutoSuggestValidAddressTypes":[5,6,32,33,34,35,13],"AutoSuggestValidSearchAreaTypes":[]},{"Lookup":{"ReportType":17,"ReportMode":1,"ReportCategory":4,"Name":"Company Report","Description":"","Abbreviation":"Cr","SamplePageCount":9,"PageZoom":"0.863","PageMarginTop":".9in","PageMarginBottom":".6in","PageMarginLeft":".30in","PageMarginRight":".30in","HtmlColor":null,"SortOrder":13,"HasBodyContent":true,"AddressCategories":[4],"Products":[1],"CommandMethods":[{"CommandMethodType":38,"Parameters":null},{"CommandMethodType":39,"Parameters":null},{"CommandMethodType":46,"Parameters":null}],"IsAvailableForProperty":false,"IsAvailableForPlace":false,"IsAvailableForSchool":false},"AutoSuggestValidAddressTypes":[],"AutoSuggestValidSearchAreaTypes":[]},{"Lookup":{"ReportType":18,"ReportMode":1,"ReportCategory":3,"Name":"Market Data Report","Description":"","Abbreviation":"Md","SamplePageCount":0,"PageZoom":"0.863","PageMarginTop":".9in","PageMarginBottom":".6in","PageMarginLeft":".30in","PageMarginRight":".30in","HtmlColor":"AECA44","SortOrder":14,"HasBodyContent":true,"AddressCategories":[4],"Products":[1],"CommandMethods":[{"CommandMethodType":47,"Parameters":null}],"IsAvailableForProperty":false,"IsAvailableForPlace":false,"IsAvailableForSchool":false},"AutoSuggestValidAddressTypes":[],"AutoSuggestValidSearchAreaTypes":[]},{"Lookup":{"ReportType":19,"ReportMode":1,"ReportCategory":3,"Name":"Market Data Report","Description":"","Abbreviation":"Md","SamplePageCount":0,"PageZoom":"0.863","PageMarginTop":".9in","PageMarginBottom":".6in","PageMarginLeft":".30in","PageMarginRight":".30in","HtmlColor":"AECA44","SortOrder":15,"HasBodyContent":true,"AddressCategories":[],"Products":[],"CommandMethods":[{"CommandMethodType":47,"Parameters":null}],"IsAvailableForProperty":false,"IsAvailableForPlace":false,"IsAvailableForSchool":false},"AutoSuggestValidAddressTypes":[],"AutoSuggestValidSearchAreaTypes":[]},{"Lookup":{"ReportType":20,"ReportMode":1,"ReportCategory":3,"Name":"Market Data Report","Description":"","Abbreviation":"Md","SamplePageCount":0,"PageZoom":"0.863","PageMarginTop":".9in","PageMarginBottom":".6in","PageMarginLeft":".30in","PageMarginRight":".30in","HtmlColor":"AECA44","SortOrder":16,"HasBodyContent":true,"AddressCategories":[],"Products":[],"CommandMethods":[{"CommandMethodType":47,"Parameters":null}],"IsAvailableForProperty":false,"IsAvailableForPlace":false,"IsAvailableForSchool":false},"AutoSuggestValidAddressTypes":[],"AutoSuggestValidSearchAreaTypes":[]}],"reportTypeFilters":null,"todaysReportCount":0,"todaysReportCountMaximum":8,"reportGeneratorUrl":"","currentUserName":"","detailLeftOffset":null,"isCurrentTabForReports":false});
});
</script>
<div id="reportNotification" targetjquery="#SiteTab_Reports">
<div class="count todaysReportCount">–</div>
<div class="detail shadow1">
<div class="container">
<div class="header clearfix">
<div class="left bold white"><span class="todaysReportCount"></span> report<span class="todaysReportCountPlural"></span> been requested today</div>
<a class="right white rightArrow" href="/reports?reporttype=ResidentialPropertyReport&amp;propertyid=27795318">Go to Reports tab</a>
<div class="right spacer rightDottedBorder white"></div>
</div>
<div class="marginLeft8 marginRight8">
<div class="rows"></div>
<div class="dottedSeparator21"></div>
<div class="clearfix"><a class="right rightArrow" href="/reports?reporttype=ResidentialPropertyReport&amp;propertyid=27795318">Go to Reports tab</a></div>
</div>
</div>
</div>
<div class="banner clearfix">
<div class="left message white"></div>
<a class="right siteButton" target="_blank"></a>
</div>
</div>
<div class="siteTabs clearfix">
<a href="/" class="left home" id="SiteTab_Home">Home</a><div class="left stSeparator"></div><a href="/search" class="left results" id="SiteTab_Results">Results</a><div class="left stSeparator"></div><a href="/homes/tx/san-antonio/78245/723-heritage-way/27795318-summary.aspx" class="left details selected" id="SiteTab_Details">Details</a><div class="left stSeparator"></div><a href="/reports?reporttype=ResidentialPropertyReport&amp;propertyid=27795318" class="left reports" id="SiteTab_Reports">Reports</a><div class="left stSeparator"></div><a href="#open-search-form" class="left icon search" id="SiteTab_Search">Search</a><div class="left stSeparator"></div><a href="/profile" class="left icon profile" id="SiteTab_Profile">Profile</a>
</div>
<div class="topLogo coBrandLogo"><a href="/">San Antonio Board of REALTORS® Inc. MLS</a></div>
<div class="topLinks">
<div class="topLinksInner clearfix">
<a class="left" href="/profile" id="TopLink_Welcome">Welcome David</a>
<div class="left separator">•</div>
<a href="/commercial" class="left" id="TopLink_Commercial">Commercial</a>
<div class="left separator">•</div>
<a href="/data-tools" class="left" id="TopLink_AdvancedDataTools">Data Tools</a>
<div class="left separator">•</div>
<a href="javascript:;" class="left signOutBtn" id="TopLink_SignOut">Sign out</a>
<div class="left signOutWait hidden">Signing out...</div>
<div class="left separator">•</div>
<div class="left orgStatusCircleShim"></div>
</div>
<a href="javascript:;" class="orgStatusCircle orgStatusCircle-1" orgstatus="1" hasanyinvalidorgagentids="False" aria-label="MLS Partner Status"></a>
</div>
</div>
</div>
</div>
<div class="freezableContent">
<div class="freezableContentOuter">
<div class="freezableContentInner siteSection">
<div class="clearfix">
<div class="pageTabs left clearfix">
<a href="/homes/tx/san-antonio/78245/723-heritage-way/27795318-summary.aspx" class="left summary selected" id="PropertyTab_Summary">Summary</a><div class="left ptSeparator"></div><a href="/homes/tx/san-antonio/78245/723-heritage-way/27795318-history.aspx" class="left history" id="PropertyTab_History">History</a><div class="left ptSeparator"></div><a href="/homes/tx/san-antonio/78245/723-heritage-way/27795318-charts.aspx" class="left charts" id="PropertyTab_Charts">Charts</a><div class="left ptSeparator"></div><a href="/homes/tx/san-antonio/78245/723-heritage-way/27795318-refinevalue.aspx" class="left refinevalue" id="PropertyTab_RefinedValue">Refined Value</a><div class="left ptSeparator"></div><a href="/homes/tx/san-antonio/78245/723-heritage-way/27795318-valuation.aspx" class="left valuation" id="PropertyTab_CompAnalysis">Comp Analysis</a><div class="left ptSeparator"></div><a href="/neighborhoods/tx/san-antonio/78245/70078245-summary.aspx" class="left" id="PropertyTab_Neighborhood">Neighborhood</a>
</div>
<a href="/reports?reporttype=ResidentialPropertyReport&amp;propertyid=27795318" class="right pageTitleCreateReport">Create a Report</a>
</div>
<div class="pageTabsBottomSeparator"></div>
<script type="text/javascript">
$(document).ready(function () { Rpr.DetailsPageHeader.Instance = new Rpr.DetailsPageHeader({"propertyId":27795318,"placeId":null,"tabId":1,"isSaved":false}); });
</script>
<div id="detailsPageHeader" class="mode-default">
<div class="clearfix">
<h1 class="left mode-default">723 Heritage Way, San Antonio, TX 78245</h1>
<div class="left mode-default marginTop10"><a href="#change-address" class="leftSeparator rightArrow">Find new address</a></div>
<div class="clearfix right marginTop6 mode-default">
<div class="left"><a href="#save" class="bgSavedStars unsaved saveBtn">Save</a></div>
<div class="left hidden"><a href="#unsave" class="bgSavedStars saved" aria-label="Unsave"></a></div>
<div class="left clearfix hidden"><div class="separator left"></div><a href="#rename" class="block padTop4 left">Rename</a></div>
<div class="left clearfix hidden"><div class="separator left"></div><a href="#reset" class="left resetIconBtn" title="Reset the name back to the original address" aria-label="Reset"></a></div>
</div>
<div class="clearfix left renameForm mode-rename">
<h2 class="left padTop2 marginRight10 marginBottom0 lightGray">Rename:</h2>
<div class="left marginTop6">
<div class="clearfix">
<div class="left marginRight10"><input type="text" class="newName hint" maxlength="50" style="background-image:url(/hint-text.ashx?Text=Enter%20new%20name&amp;Height=22);" aria-label="Enter new name" /></div>
<div class="left marginRight10"><a class="siteButton" href="#ok">OK</a></div>
<div class="left textNextToSiteButton"><a href="#cancel-rename">Cancel</a></div>
<div class="left textNextToSiteButton wait hidden">Please wait...</div>
</div>
<div class="marginTop7 lightGray fs14">723 Heritage Way, San Antonio, TX 78245</div>
</div>
</div>
<div class="clearfix changeAddrForm mode-changeAddr">
<div class="clearfix left changeAddrTipAndQuery roundLeftBorders10">
<div class="left changeAddrQueryTip">Enter address for property details, or area for neighborhood details</div>
<div class="left"><input type="text" class="textbox hint hint-addrCityStateZipCountyMls-2 changeAddrQuery" id="ChangeAddressForm_QueryTxt" maxlength="100" tabindex="0" aria-label="Enter address for property details, or area for neighborhood details" /></div>
</div>
<a class="left marginRight15 siteButton changeAddrSubmitBtn" href="#submit" id="ChangeAddressForm_SubmitBtn">Submit</a>
<a href="../../../../../controls/#cancel" class="left changeAddrCancelBtn">Cancel</a>
<div class="left changeAddrWait hidden">Please wait...</div>
</div>
</div>
<div class="address marginTop5 lightGray fs14 hidden">723 Heritage Way, San Antonio, TX 78245</div>
</div>
</div>
</div>
</div>
<div class="siteContentContainer" jstcache="0">
<div class="siteSection siteContentOuter" jstcache="0">
<div class="siteContentInner" jstcache="0">
<div class="detailsLayout propertyPage" jstcache="0">
<div class="fullWidthMapControlOuter hidden">
<div id="mapToolbar" class="">
<div class="tools clearfix">
<div class="left marginRight8 marginTop11 padTop4 bold black">Map Tools:</div>
<div class="left clearfix marginTop10">
<div class="left marginRight8 marginTop1">
<select class="tbDrawingTools" aria-label="Draw a shape">
<option value="">Draw a shape</option>
<option value="drawBox">Box</option>
<option value="drawRadius">Radius</option>
<option value="drawPolygon">Polygon</option>
</select>
</div>
<div class="left marginRight8 marginTop1">
<select class="tbPinTools" aria-label="Use a map pin">
<option value="">Use a map pin</option>
<option value="driveTime">Drive Time</option>
<option value="distance">Distance</option>
</select>
</div>
<div class="left marginRight8 marginTop1">
<select class="tbSavedAreas" aria-label="Use a custom area" data-custom-areas="[]"><option value="">Use a custom area</option><option value="create">Create a new one</option></select>
</div>
<div class="left marginRight8 marginTop1">
<select class="tbGeographies" aria-label="Geography" data-show-text="Show geographies" data-hide-text="Hide geographies" mapzoomlevel="18"><option value="0">Show geographies</option><option value="24" longdescription="">Census Block Groups</option></select>
</div>
</div>
<div class="right marginTop10 padTop4"><a href="#reset-map" class="disabled">Reset Map</a></div>
</div>
<div class="instrConnector hidden"></div>
<div class="instructions hidden">
<div class="content"></div>
</div>
</div>
<div class="hidden">
</div>
<div class="mapControlInner"></div>
</div>
<div class="dlColumns clearfix" jstcache="0">
<div class="dlLeftColumn" jstcache="0">
<div class="sumBasicFactsAndPhotos" jstcache="0">
<div id="PropertySummary_StatusFlag">
<div class="propertyStatusFlag propertyStatusFlagOneLine clearfix"><div class="flag flag-1"></div><div class="descr">Sold Date: 9/27/2004, Public Record</div></div>
</div>
<div class="dottedSeparator31"></div>
<div class="sumBasicFacts">
<div class="clearfix">
<div class="left priceSection sectionSeparator">
<div class="clearfix">
<div class="left text">RVM<sup>®</sup></div>
<div class="left marginLeft5"><img src="http://static.narrpr.com/1.66.29.2/images/misc/clear.gif" class="infoBtn balloonTip" balloontiptext="&lt;p&gt;In some markets, RPR displays &lt;strong&gt;Realtors Valuation Model&amp;reg; (RVM&amp;reg;)&lt;/strong&gt; property estimates in addition to or instead of Automated Valuation Model (AVM) estimates. RVMs are similar to AVMs but also factor in MLS listing, sales and off-market data to yield a more accurate home valuation. RPR is rolling out RVMs in phases across the country. RVMs are displayed for a property only if criteria for an accurate result are fulfilled, such as having a minimum of two comps from active or inactive listings to help calculate the estimate.&lt;/p&gt;" alt="Info" balloontipinitialized="true" /></div>
</div>
<div class="price priceGray">$168,050</div>
<div class="footerText">Last RVM<sup>®</sup> Update:<br />1/16/2018</div>
<div><a href="javascript:;" class="viewCompsLink rightArrow">View Details</a></div>
</div>
<div class="left refineValSection notRefined sectionSeparator">
<a href="/homes/tx/san-antonio/78245/723-heritage-way/27795318-refinevalue.aspx" class="siteButton" id="PropertySummary_RefineValue">Refine</a>
<div>Change the RVM<sup>®</sup> estimate for this property.</div>
</div>
<div class="left refineValSection refined sectionSeparator hidden">
<div class="text">Your Refined Value</div>
<div class="price">$168,050</div>
<a href="/homes/tx/san-antonio/78245/723-heritage-way/27795318-refinevalue.aspx" class="rightArrow">Edit</a>
</div>
<div class="left createValSection create">
<a href="/homes/tx/san-antonio/78245/723-heritage-way/27795318-valuation.aspx" class="siteButton" id="PropertySummary_CreateCompAnalysis">Create</a>
<div>Build a Comp Analysis for this property.</div>
</div>
</div>
<div class="dottedSeparator31"></div>
<div class="clearfix">
<div class="left factsSection basicFacts sectionSeparator">
<div class="factsSectionInner">
<div class="item basicFactsHeading">Basic Facts <img src="http://static.narrpr.com/1.66.29.2/images/misc/clear.gif" class="infoBtn balloonTip" balloontiptext="&lt;p&gt;&lt;span&gt;A property's &quot;Basic Facts&quot; derive from Listing and Public Records sources. Listing data displays here if the property is on market. Public records data displays for&amp;nbsp;&lt;/span&gt;&lt;span&gt;Beds, Baths and Living Area (instead of listing data), if the listing data is more than three years ago. Available listing data will also be displayed if no public records are available for a property.&amp;nbsp;&lt;/span&gt;&lt;span&gt;&lt;br /&gt;&lt;/span&gt;&lt;/p&gt;" alt="Info" balloontipinitialized="true" /></div>
<div class="item value nowrap">4 Bedrooms   3 Bathrooms</div><div class="item">Home Type: <span class="value nowrap">Single Family Residence</span></div><div class="item">Living Area: <span class="value nowrap">2,170 sq ft</span></div><div class="item">Est. Value / sq ft: <span class="value">$77</span></div><div class="item">Owner: <span class="value">Jones Patrick Clayton</span></div>
</div>
</div>
<div class="left factsSection">
<div class="factsSectionInner">
<div class="item">RVM<sup>®</sup> Est. Range: <span class="value">$146,204 – $189,896</span></div><div class="item clearfix">
<div class="left marginRight5">RVM<sup>®</sup> Confidence:</div>
<div class="left confidenceScore confidenceScore-4" origscore="87"></div>
<div class="left marginLeft3 marginTop3"><a href="javascript:;" class="infoBtn balloonTip" balloontiptext='&lt;p&gt;The RVM&reg; estimates displayed on RPR are the product of multiple Realtors Valuation Model&reg; calculations, each of which uses proprietary algorithms and arrives at its own estimate. The &lt;strong&gt;RVM Confidence Score&lt;/strong&gt; is a value between zero and five stars that indicates the level to which each of the multiple models agrees with the other estimated values. High confidence scores indicate that the different models yield similar estimates for this property. Learn more in our Help Desk: &lt;a href="http://support.narrpr.com/entries/183465-what-is-an-avm-or-rvm-confidence-score"&gt;What is an AVM or RVM Confidence Score?&lt;/a&gt;&lt;/p&gt;' aria-label="Confidence Score Description" balloontipinitialized="true"></a></div>
</div>
<div class="item estChange estChangeDown">RVM<sup>®</sup> Change - Last 1 Month: <span class="value">-$890</span></div>
<div class="item estChange estChangeDown">RVM<sup>®</sup> Change - Last 12 Months: <span class="value">-0.6%</span></div>
<div class="item"><a href="#rvm-agent-to-agent" class="rightArrow videoDialogLink" vimeovideoid="122545178" videotitle="Using the RVM&lt;sup&gt;®&lt;/sup&gt; in Pricing Discussions" videofooterlinktext="More RPR Training" videofooterlinkurl="http://blog.narrpr.com/training" videodialoglinkinitialized="true">Using the RVM<sup>®</sup> in Pricing Discussions</a></div>
</div>
</div>
<div class="propertyPromo roundBorder5 right">
<div class="promoItem zipFormPromo separator">
<div class="icon"></div>
<a href="#zip-form-tx" class="zipFormTxBtn rightArrow" data-is-linked="false" data-confirm-dialog-url="/link-to-partner-proxy?url=http%3a%2f%2fws.zipformonline.com%2fcorews%2fssologin.aspx%3fappKey%3d7AD4753D-848C-47DE-8AB1-2652323E6724%26nrdsId%3d824062692%26mlsUsername%3d%26mlsPassword%3d%26mlsClass%3d%26listingId%3d%26updTxn%3dfalse%26openVw%3dtrue%26extid%3dd6dcd719-f0b9-48c8-9386-6374561aab30%26extUn%3dDavid%2520Cruz%2520Alvarado&amp;ssocode=zipform" data-homepage-url="https://www.zipformonline.com/Shibboleth.sso/Login?SAMLDS=1&amp;target=https://www.zipformonline.com/secure/samlsso.aspx&amp;entityID=http://www.narrpr.com" data-sso-code="zipform" data-transaction-types='[{"Value":"Listing","Description":"Listing"},{"Value":"Purchase","Description":"Purchase"},{"Value":"Lease","Description":"Lease"}]'>zipForm® Transactions</a>
</div>
<div class="promoItem valuatePromo separator">
<div class="icon"></div>
<a href="/valuate-property-analysis?propertyid=27795318" class="valuatePromoBtn rightArrow" target="_blank">Property Analysis for Investors</a>
</div>
<div class="promoItem trainingPromo">
<div class="icon"></div>
<a href="http://blog.narrpr.com/training/" target="_blank" class="externalLink rightArrow" externallinkinitialized="true">Training, Videos and RPR Seminars</a>
</div>
</div>
</div>
<div class="dottedSeparator31"></div>
</div>
<div class="clearfix marginBottom8 propImageryLinks">
<a href="#street-view" class="left rightSeparator selected">Street View</a><a href="#overhead-view" class="left">Overhead View</a>
</div>
<div class="propImageryCont" jstcache="0">
<div id="propImageryStreetViewMap" class="mapContainer mapContainer-propertySummary" jstcache="0" style="position: relative; background-color: rgb(229, 227, 223); overflow: hidden;"><div class="gm-style" jstcache="0" style="position: absolute; z-index: 1; left: 0px; top: 0px; height: 100%; width: 100%; padding: 0px; border-width: 0px; margin: 0px;"><div tabindex="-1" style="position: absolute; z-index: 0; left: 0px; top: 0px; height: 100%; width: 100%; padding: 0px; border-width: 0px; margin: 0px; background-color: rgb(229, 227, 223);" jstcache="0"><div style='z-index: 1; position: absolute; top: 0px; left: 0px; width: 100%; height: 100%; cursor: url("http://maps.gstatic.com/mapfiles/openhand_8_8.cur") 8 8, default;' jstcache="0"><div style="position: absolute; left: 0px; top: 0px; z-index: 100; width: 100%;"></div><div style="position: absolute; left: 0px; top: 0px; z-index: 101; width: 100%;"></div><div style="position: absolute; left: 0px; top: 0px; z-index: 102; width: 100%;"></div><div style="position: absolute; left: 0px; top: 0px; z-index: 103; width: 100%;"></div><div style="position: absolute; left: 0px; top: 0px; z-index: 104; width: 100%;"></div><div style="position: absolute; left: 0px; top: 0px; z-index: 105; width: 100%;"></div><div style="position: absolute; left: 0px; top: 0px; z-index: 106; width: 100%;"></div><div style="position: absolute; left: 0px; top: 0px; z-index: 107; width: 100%;"></div><div class="gmnoprint" style="position: absolute; left: 0px; top: 0px; z-index: 2; font-family: Roboto, Arial, sans-serif;"><svg xmlns="http://www.w3.org/2000/svg" version="1.1" width="591px" height="467px" viewbox="0 0 591 467" style="position: absolute; left: 0px; top: 0px; pointer-events: none;"><path fill="black" fill-rule="evenodd" fill-opacity="0.5" stroke="none" d="M 0 -100 L 40 -60 L 30 -50 L 0 -82 L -30 -50 L -40 -60" transform="translate(295.5 368.3112878557776) scale(1 0.31698729810778065) rotate(74.80602355498206) " style="pointer-events: all;"></path><path fill="white" fill-rule="evenodd" fill-opacity="1" stroke="none" d="M 0 -100 L 40 -60 L 30 -50 L 0 -82 L -30 -50 L -40 -60" transform="translate(295.5 365.3112878557776) scale(1 0.31698729810778065) rotate(74.80602355498206) " style="pointer-events: all;"></path><path fill="white" fill-rule="evenodd" fill-opacity="0" stroke="none" d="M 0 -120 L 60 -60 L 40 -30 L -40 -30 L -60 -60 L 0 -120" pano="WE_CV-c9Fzka3_yXUEUeMg" cursor="pointer" transform="translate(295.5 365.3112878557776) scale(1 0.31698729810778065) rotate(74.80602355498206) " style="pointer-events: all;"></path><path fill="black" fill-rule="evenodd" fill-opacity="0.5" stroke="none" d="M 0 -100 L 40 -60 L 30 -50 L 0 -82 L -30 -50 L -40 -60" transform="translate(295.5 368.3112878557776) scale(1 0.31698729810778065) rotate(255.12973876494303) " style="pointer-events: all;"></path><path fill="white" fill-rule="evenodd" fill-opacity="1" stroke="none" d="M 0 -100 L 40 -60 L 30 -50 L 0 -82 L -30 -50 L -40 -60" transform="translate(295.5 365.3112878557776) scale(1 0.31698729810778065) rotate(255.12973876494303) " style="pointer-events: all;"></path><path fill="white" fill-rule="evenodd" fill-opacity="0" stroke="none" d="M 0 -120 L 60 -60 L 40 -30 L -40 -30 L -60 -60 L 0 -120" pano="pxwlE6yqHCNbcOh-p135tA" cursor="pointer" transform="translate(295.5 365.3112878557776) scale(1 0.31698729810778065) rotate(255.12973876494303) " style="pointer-events: all;"></path></svg></div><div jstcache="0" style="width: 100%; height: 100%;"><div jstcache="5" aria-label="Street View" tabindex="0" jsaction="click: scene.viewport;dblclick: scene.viewport;mousedown: scene.viewport;mousemove: scene.viewport;mouseup: scene.viewport;mouseover: scene.viewport;mouseout: scene.viewport;touchstart: scene.viewport;touchmove: scene.viewport;touchend: scene.viewport;pointerdown: scene.viewport;pointermove: scene.viewport;pointerup: scene.viewport;pointercancel: scene.viewport;MSPointerDown: scene.viewport;MSPointerMove: scene.viewport;MSPointerUp: scene.viewport;MSPointerCancel: scene.viewport;contextmenu: scene.viewport;keydown: scene.viewport;keyup: scene.viewport;wheel: scene.viewport;mousewheel: scene.viewport;DOMMouseScroll: scene.viewport;" role="main" class="widget-scene" style="cursor: auto;"> <canvas width="1182" height="934" id="" class="widget-scene-canvas" style="width: 591px; height: 467px;"></canvas> <div id="" class="widget-scene-imagery-render" style="width: 0px; height: 0px; display: none;"></div> <div class="widget-scene-effects noprint"></div> </div></div></div></div><div style="margin-left: 5px; margin-right: 5px; z-index: 1000000; position: absolute; left: 0px; bottom: 0px;"><a target="_blank" href="https://maps.google.com/maps/@29.4352066,-98.6842364,0a,41.1y,-2.18h,90t/data=!3m4!1e1!3m2!1sCuftsMK5Hz2LP8GjDOTShg!2e0?source=apiv3" title="Click to see this area on Google Maps" style="position: static; overflow: visible; float: none; display: inline;"><div style="width: 66px; height: 26px; cursor: pointer;"><img alt="" src="http://maps.gstatic.com/mapfiles/api-3/images/google_white5_hdpi.png" draggable="false" style="position: absolute; left: 0px; top: 0px; width: 66px; height: 26px; user-select: none; border: 0px; padding: 0px; margin: 0px;" /></div></a></div><div style="background-color: white; padding: 15px 21px; border: 1px solid rgb(171, 171, 171); font-family: Roboto, Arial, sans-serif; color: rgb(34, 34, 34); box-shadow: rgba(0, 0, 0, 0.2) 0px 4px 16px; z-index: 10000002; display: none; width: 256px; height: 148px; position: absolute; left: 146px; top: 144px;"><div style="padding: 0px 0px 10px; font-size: 16px;">Map Data</div><div style="font-size: 13px;">© 2018 Google</div><div style="width: 13px; height: 13px; overflow: hidden; position: absolute; opacity: 0.7; right: 12px; top: 12px; z-index: 10000; cursor: pointer;"><img alt="" src="http://maps.gstatic.com/mapfiles/api-3/images/mapcnt6.png" draggable="false" style="position: absolute; left: -2px; top: -336px; width: 59px; height: 492px; user-select: none; border: 0px; padding: 0px; margin: 0px; max-width: none;" /></div></div><div class="gmnoprint" style="z-index: 1000001; position: absolute; right: 170px; bottom: 0px; width: 79px;"><div draggable="false" class="gm-style-cc" style="user-select: none; height: 14px; line-height: 14px;"><div style="opacity: 0.7; width: 100%; height: 100%; position: absolute;"><div style="width: 1px;"></div><div style="background-color: rgb(0, 0, 0); width: auto; height: 100%; margin-left: 1px;"></div></div><div style="position: relative; padding-right: 6px; padding-left: 6px; font-family: Roboto, Arial, sans-serif; font-size: 10px; color: rgb(255, 255, 255); white-space: nowrap; direction: ltr; text-align: right; vertical-align: middle; display: inline-block;"><a style="color: rgb(68, 68, 68); text-decoration: none; cursor: pointer; display: none;">Map Data</a><span style="">© 2018 Google</span></div></div></div><div class="gmnoscreen" style="position: absolute; right: 0px; bottom: 0px;"><div style="font-family: Roboto, Arial, sans-serif; font-size: 11px; color: rgb(68, 68, 68); direction: ltr; text-align: right; background-color: rgb(245, 245, 245);">© 2018 Google</div></div><div class="gmnoprint gm-style-cc" draggable="false" style="z-index: 1000001; user-select: none; height: 14px; line-height: 14px; position: absolute; right: 95px; bottom: 0px;"><div style="opacity: 0.7; width: 100%; height: 100%; position: absolute;"><div style="width: 1px;"></div><div style="background-color: rgb(0, 0, 0); width: auto; height: 100%; margin-left: 1px;"></div></div><div style="position: relative; padding-right: 6px; padding-left: 6px; font-family: Roboto, Arial, sans-serif; font-size: 10px; color: rgb(255, 255, 255); white-space: nowrap; direction: ltr; text-align: right; vertical-align: middle; display: inline-block;"><a href="https://www.google.com/intl/en-US_US/help/terms_maps.html" target="_blank" style="text-decoration: none; cursor: pointer; color: rgb(255, 255, 255);">Terms of Use</a></div></div><button draggable="false" title="Toggle fullscreen view" aria-label="Toggle fullscreen view" type="button" style="background: none; border: 0px; margin: 10px 20px; padding: 0px; position: absolute; cursor: pointer; user-select: none; width: 25px; height: 25px; overflow: hidden; top: 0px; right: 0px;"><img alt="" src="http://maps.gstatic.com/mapfiles/api-3/images/sv9.png" draggable="false" class="gm-fullscreen-control" style="position: absolute; left: 0px; top: -86px; width: 164px; height: 175px; user-select: none; border: 0px; padding: 0px; margin: 0px;" /></button><div class="gmnoprint gm-bundled-control gm-bundled-control-on-bottom" draggable="false" controlwidth="48" controlheight="113" style="margin: 10px; user-select: none; position: absolute; bottom: 127px; right: 48px;" jstcache="0"><div class="gmnoprint" controlwidth="28" controlheight="55" style="position: absolute; left: 10px; top: 58px;"><div draggable="false" style="user-select: none; box-shadow: rgba(0, 0, 0, 0.3) 0px 1px 4px -1px; border-radius: 2px; cursor: pointer; background-color: rgb(34, 34, 34); width: 28px; height: 55px;"><button draggable="false" title="Zoom in" aria-label="Zoom in" type="button" style="background: none; display: block; border: 0px; margin: 0px; padding: 0px; position: relative; cursor: pointer; user-select: none; width: 28px; height: 27px; top: 0px; left: 0px;"><div style="overflow: hidden; position: absolute; width: 15px; height: 15px; left: 7px; top: 6px;"><img alt="" src="http://maps.gstatic.com/mapfiles/api-3/images/tmapctrl_hdpi.png" draggable="false" style="position: absolute; left: -60px; top: 0px; user-select: none; border: 0px; padding: 0px; margin: 0px; max-width: none; width: 120px; height: 54px;" /></div></button><div style="position: relative; overflow: hidden; width: 67%; height: 1px; left: 16%; background-color: rgb(26, 26, 26); top: 0px;"></div><button draggable="false" title="Zoom out" aria-label="Zoom out" type="button" style="background: none; display: block; border: 0px; margin: 0px; padding: 0px; position: relative; cursor: pointer; user-select: none; width: 28px; height: 27px; top: 0px; left: 0px;"><div style="overflow: hidden; position: absolute; width: 15px; height: 15px; left: 7px; top: 6px;"><img alt="" src="http://maps.gstatic.com/mapfiles/api-3/images/tmapctrl_hdpi.png" draggable="false" style="position: absolute; left: -60px; top: -15px; user-select: none; border: 0px; padding: 0px; margin: 0px; max-width: none; width: 120px; height: 54px;" /></div></button></div></div><div dir="ltr" controlwidth="48" controlheight="48" style="position: absolute; left: 0px; top: 0px;" jstcache="0"><div jstcache="73" class="gm-compass"> <div class="gm-compass-icon gm-compass-background"></div> <div jstcache="34" jsaction="compass.north" class="gm-compass-icon gm-compass-needle" style="-webkit-transform: rotate(2.1778649856461243deg);-ms-transform: rotate(2.1778649856461243deg);-moz-transform: rotate(2.1778649856461243deg);transform: rotate(2.1778649856461243deg)" jsan="7.gm-compass-icon,7.gm-compass-needle,4.style,22.jsaction"></div> <div jsaction="compass.counterclockwise" class="gm-compass-icon gm-compass-turn"></div> <div jsaction="compass.clockwise" class="gm-compass-icon gm-compass-turn gm-compass-turn-opposite"></div> <div> <div class="gm-compass-tooltip-text"> Rotate the view </div> <div class="gm-compass-arrow-right gm-compass-arrow-right-outer"></div> <div class="gm-compass-arrow-right gm-compass-arrow-right-inner"></div> </div> </div></div><div draggable="false" controlwidth="25px" style="user-select: none; font-family: Roboto, Arial, sans-serif; font-size: 11px; width: 25px; text-align: center; box-shadow: rgba(0, 0, 0, 0.3) 0px 1px 4px -1px; cursor: pointer; display: none; position: absolute;"></div></div><div dir="ltr" jstcache="0" style="z-index: 24601; position: absolute; display: none; left: 0px; top: 0px;"><div jstcache="45" class="gm-iv-container gm-iv-small-container" jsan="t-_EPk2VOG1I0,7.gm-iv-container,7.gm-iv-small-container"> <div jsaction="closeControl.click" class="gm-iv-close"> <div class="gm-iv-back"> <div jstcache="42" class="gm-iv-back-icon-background gm-iv-back-icon" jsan="7.gm-iv-back-icon-background,7.gm-iv-back-icon"> </div> </div> </div> </div></div><div dir="ltr" style="display: none; position: absolute; left: 0px; top: 0px;" jstcache="0"><div jstcache="74" class="gm-iv-address" jsan="t-bDow0pNywiw,7.gm-iv-address"> <div class="gm-iv-address-description"> <div jstcache="47" class="gm-iv-short-address-description" jsan="7.gm-iv-short-address-description">723 Heritage Way</div> <div jstcache="48" class="gm-iv-long-address-description" jsan="7.gm-iv-long-address-description">San Antonio, Texas</div> <div jstcache="49" class="gm-iv-profile-url" style="display:none"> <a target="_blank" jstcache="50"> <div jstcache="51" class="gm-iv-profile-link" jsan="7.gm-iv-profile-link"></div> </a> </div> </div> <div jstcache="52" class="gm-iv-address-link"> <a target="_blank" jstcache="53" href="https://www.google.com/maps/@29.4352066,-98.6842364,0a,41.1y,-2.18h,90t/data=!3m4!1e1!3m2!1sCuftsMK5Hz2LP8GjDOTShg!2e0?source=apiv3"> View on Google Maps </a> </div> <div jstcache="54" class="gm-iv-address-custom" style="display:none"> <p>Custom Imagery</p> </div> <div jstcache="55" class="gm-iv-vertical-separator"></div> <div jstcache="56" class="gm-iv-marker"> <a target="_blank" jstcache="57" href="https://www.google.com/maps/@29.43520664734636,-98.68423637806313,13z?hl=en-US&amp;gl=US"> <div class="gm-iv-marker-icon gm-iv-marker-icon-background"></div> </a> </div> <div jstcache="58" class="gm-iv-timeline" style="display:none"> <div class="gm-iv-horizontal-separator"></div> <div jstcache="59" jsaction="timeline.show" class="gm-iv-timeline-wrapper" style="display:none"> <div jstcache="60" class="gm-iv-timeline-icon-wrapper" style="display:none"> <div class="gm-iv-timeline-icon gm-iv-timeline-icon-background"></div> </div> <div jstcache="61" class="gm-iv-timeline-description" style="display:none"> <div jstcache="62" class="gm-iv-timeline-description-details" jsan="7.gm-iv-timeline-description-details"></div> <div class="gm-iv-timeline-description-separator">-</div> <div jstcache="63" class="gm-iv-timeline-description-details" jsan="7.gm-iv-timeline-description-details"></div> </div> </div> <div jstcache="64" class="gm-iv-timeline-description" style="display:none"> <div jstcache="65" class="gm-iv-timeline-description-details" jsan="7.gm-iv-timeline-description-details"></div> <div class="gm-iv-timeline-description-separator">-</div> <div jstcache="66" class="gm-iv-timeline-description-details" jsan="7.gm-iv-timeline-description-details"></div> </div> </div> </div><div style="position: absolute; left: 0px; margin-top: -29px; width: 351px; height: 248px; display: none;"></div></div><div style="position: absolute; background-color: rgb(34, 34, 34); border-radius: 2px; width: 28px; height: 28px; margin-right: 10px; overflow: hidden; z-index: 1; display: none; bottom: 147px; right: 0px;"><img alt="" src="http://maps.gstatic.com/mapfiles/api-3/images/sv9.png" draggable="false" style="position: absolute; left: -103px; top: -84px; width: 164px; height: 175px; user-select: none; border: 0px; padding: 0px; margin: 0px;" /></div><div draggable="false" style="color: white; font-family: Roboto, Arial, sans-serif; background-color: black; padding: 4px; border: 2px solid white; user-select: none; display: none; position: absolute; left: 296px; top: 234px;">This image is no longer available</div><div draggable="false" class="gm-style-cc" style="user-select: none; height: 14px; line-height: 14px; position: absolute; right: 0px; bottom: 0px;"><div style="opacity: 0.7; width: 100%; height: 100%; position: absolute;"><div style="width: 1px;"></div><div style="background-color: rgb(0, 0, 0); width: auto; height: 100%; margin-left: 1px;"></div></div><div style="position: relative; padding-right: 6px; padding-left: 6px; font-family: Roboto, Arial, sans-serif; font-size: 10px; color: rgb(255, 255, 255); white-space: nowrap; direction: ltr; text-align: right; vertical-align: middle;"><a target="_new" title="Report problems with Street View imagery to Google" href="https://www.google.com/cbk?cb_client=apiv3&amp;output=report&amp;image_key=!1e2!2sCuftsMK5Hz2LP8GjDOTShg&amp;cbp=1,-2.178,,1,0&amp;hl=en-US" style="text-decoration: none; color: rgb(255, 255, 255);">Report a problem</a></div></div></div></div>
<div id="propImageryOverheadViewMap" class="mapContainer mapContainer-propertySummary hidden"></div>
</div>
<div class="dottedSeparator21"></div>
<div class="rpr-propertyNote" enableautosave="True">
<div class="clearfix">
<div class="left bold marginRight8 padTop2">Notes:</div>
<div class="checkbox left invisible clearfix">
<input type="checkbox" id="RprCheckbox_24" propertyname="IsNotePublic" class="checkbox" checked="checked" /><label for="RprCheckbox_24" class="checkbox">Include in My Reports</label>
</div>
</div>
<textarea propertyname="NoteText" class="marginTop3 hint" style="background-image:url(/hint-text.ashx?Text=Add%20note%20here);" maxlength="1000" rows="6" aria-label="Notes for Main"></textarea>
<input type="hidden" value="27795318" propertyname="PropertyId" />
<input type="hidden" value="" propertyname="NoteId" />
<input type="hidden" value="1" propertyname="ContentType" />
<input type="hidden" value="1" propertyname="NoteSection" />
<input type="hidden" value="1" propertyname="Product" />
<input type="hidden" value="" propertyname="BatchId" />
<input type="hidden" value="1" propertyname="AppPropertyMode" />
<div class="clearfix marginTop3">
<div class="left noteStatus"></div>
<div class="right charCount">(1000 characters left)</div>
</div>
</div>
</div>
<script type="text/javascript">
$(document).ready(function ()
{
Rpr.PropertyGeneralNotes({"PropertyId":27795318,"ReportCoverPagePhotoNoteId":null,"SellerProceeds":[{"LowValue":null,"HighValue":null,"SellerProceedItemId":1,"CategoryDescription":"Price","Description":null},{"LowValue":null,"HighValue":null,"SellerProceedItemId":2,"CategoryDescription":"Encumbrances","Description":"First Loan"},{"LowValue":null,"HighValue":null,"SellerProceedItemId":3,"CategoryDescription":"Encumbrances","Description":"Second Loan"},{"LowValue":null,"HighValue":null,"SellerProceedItemId":4,"CategoryDescription":"Estimated Closing Costs","Description":"Commissions"},{"LowValue":null,"HighValue":null,"SellerProceedItemId":5,"CategoryDescription":"Estimated Closing Costs","Description":"Escrow Items"},{"LowValue":null,"HighValue":null,"SellerProceedItemId":6,"CategoryDescription":"Estimated Closing Costs","Description":"Escrow Fees"},{"LowValue":null,"HighValue":null,"SellerProceedItemId":7,"CategoryDescription":"Estimated Closing Costs","Description":"Home Warranty"},{"LowValue":null,"HighValue":null,"SellerProceedItemId":8,"CategoryDescription":"Estimated Closing Costs","Description":"Other Work"},{"LowValue":null,"HighValue":null,"SellerProceedItemId":9,"CategoryDescription":"Estimated Closing Costs","Description":"Pest Inspection"},{"LowValue":null,"HighValue":null,"SellerProceedItemId":10,"CategoryDescription":"Estimated Closing Costs","Description":"Tax Stamp"},{"LowValue":null,"HighValue":null,"SellerProceedItemId":11,"CategoryDescription":"Estimated Closing Costs","Description":"Termite Work"},{"LowValue":null,"HighValue":null,"SellerProceedItemId":12,"CategoryDescription":"Estimated Closing Costs","Description":"Title Insurance"},{"LowValue":null,"HighValue":null,"SellerProceedItemId":17,"CategoryDescription":"Seller Concessions","Description":null},{"LowValue":null,"HighValue":null,"SellerProceedItemId":18,"CategoryDescription":"Seller Conveyances","Description":null},{"LowValue":null,"HighValue":null,"SellerProceedItemId":13,"CategoryDescription":"Other","Description":null},{"LowValue":null,"HighValue":null,"SellerProceedItemId":16,"CategoryDescription":"Net Cash to Seller","Description":null}]});
});
</script>
<div id="property-notes" class="fragment"></div>
<div id="property-notes-panel" class="collapsiblePanel">
<div class="cpHeading cpHeadingGeorgia"><a href="javascript:;" class="cpToggleBtn">Property Notes</a></div>
<div class="cpContent propGeneralNotes">
<div class="clearfix newNoteButtonsCont">
<a href="#add-text-note" class="left siteButton marginRight10">Add a Note</a>
<a href="#upload-photos" class="left siteButton marginRight10">Upload Photos</a>
<a href="#seller-proceeds" class="left siteButton">Seller's Proceeds</a>
</div>
<div class="dottedSeparator21"></div>
<div class="noNotesLabel tipLabel">No property notes available...</div>
</div>
<div class="boldSeparator25"></div>
</div>
<div id="homeowner-facts" class="fragment"></div>
<div id="homeowner-facts-panel" class="collapsiblePanel">
<div class="cpHeading cpHeadingGeorgia"><a href="javascript:;" class="cpToggleBtn">Homeowner Facts</a><span class="cpHeadingText2">(from Public Records)</span></div>
<div class="cpContent">
<div class="basicNameValuePairs"><div class="clearfix"><div class="left col1"><div class="item"><span class="name">Owner Name (Public)</span>: Jones Patrick Clayton</div><div class="item"><span class="name">Mailing Address</span>: <br />723 Heritage Way San Antonio TX 78245-1169</div></div><div class="left col2"><div class="item"><span class="name">Owner Occupied</span>: Yes</div></div></div></div>
</div>
<div class="boldSeparator25"></div>
</div>
<div id="home-facts" class="fragment"></div>
<div id="home-facts-panel" class="collapsiblePanel">
<div class="cpHeading cpHeadingGeorgia"><a href="javascript:;" class="cpToggleBtn">Home Facts</a></div>
<div class="cpContent">
<script type="text/javascript">
$(document).ready(function ()
{
Rpr.PropertySummaryFacts.initialize({"FactViewInfo":{"FactView":2,"AnalysisType":null,"AreOnlyFactsWithValuesShown":true,"CanNewFactsBeAdded":true,"CanFactsBeEdited":true,"AreCustomFactsShown":true,"AreCustomFactsExpanded":false,"UseShortDescriptions":false,"IsPrimaryConfirmFactsView":false,"IsPrimaryAdjustmentsView":false,"Rows":[{"RowId":1,"Description":"Property Type","IsAlwaysShown":true,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":1,"DataType":5,"Format":6,"MaxLength":null,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":1,"DataType":5,"Format":6,"MaxLength":null,"AreZerosDisplayed":false}],"Tag":null},{"RowId":26,"Description":"Property Subtype","IsAlwaysShown":true,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":2,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":2,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":2,"Description":"Bedrooms","IsAlwaysShown":true,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":13,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":13,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false}],"Tag":null},{"RowId":3,"Description":"Total Baths","IsAlwaysShown":true,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":15,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":15,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false}],"Tag":null},{"RowId":4,"Description":"Full Baths","IsAlwaysShown":true,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":18,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":18,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false}],"Tag":null},{"RowId":5,"Description":"Partial Baths","IsAlwaysShown":true,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":20,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":20,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false}],"Tag":null},{"RowId":6,"Description":"Living Area (sq ft)","IsAlwaysShown":true,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":8,"DataType":2,"Format":14,"MaxLength":6,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":8,"DataType":2,"Format":14,"MaxLength":6,"AreZerosDisplayed":false},{"FactTypeId":7,"DataType":2,"Format":14,"MaxLength":10,"AreZerosDisplayed":false}],"Tag":null},{"RowId":29,"Description":"Living Area sq ft range (low)","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":63,"DataType":2,"Format":14,"MaxLength":6,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":63,"DataType":2,"Format":14,"MaxLength":6,"AreZerosDisplayed":false}],"Tag":null},{"RowId":30,"Description":"Living Area sq ft range (high)","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":64,"DataType":2,"Format":14,"MaxLength":6,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":64,"DataType":2,"Format":14,"MaxLength":6,"AreZerosDisplayed":false}],"Tag":null},{"RowId":7,"Description":"Lot Size","IsAlwaysShown":true,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":6,"DataType":2,"Format":18,"MaxLength":10,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":6,"DataType":2,"Format":18,"MaxLength":10,"AreZerosDisplayed":false}],"Tag":null},{"RowId":27,"Description":"Lot Dimensions","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":62,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":62,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":28,"Description":"Tenure","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":56,"DataType":5,"Format":16,"MaxLength":null,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":56,"DataType":5,"Format":16,"MaxLength":null,"AreZerosDisplayed":false}],"Tag":null},{"RowId":8,"Description":"Basement (sq ft)","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":25,"DataType":2,"Format":14,"MaxLength":10,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":25,"DataType":2,"Format":14,"MaxLength":10,"AreZerosDisplayed":false}],"Tag":null},{"RowId":9,"Description":"Garage","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":27,"DataType":3,"Format":7,"MaxLength":null,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":27,"DataType":3,"Format":7,"MaxLength":null,"AreZerosDisplayed":false},{"FactTypeId":31,"DataType":1,"Format":1,"MaxLength":20,"AreZerosDisplayed":false},{"FactTypeId":32,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":10,"Description":"Garage (spaces)","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":28,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":true},"FactTypeInfos":[{"FactTypeId":28,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":true}],"Tag":null},{"RowId":11,"Description":"Pool","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":46,"DataType":3,"Format":7,"MaxLength":null,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":46,"DataType":3,"Format":7,"MaxLength":null,"AreZerosDisplayed":false},{"FactTypeId":47,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":12,"Description":"Year Built","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":44,"DataType":2,"Format":3,"MaxLength":4,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":44,"DataType":2,"Format":3,"MaxLength":4,"AreZerosDisplayed":false}],"Tag":null},{"RowId":13,"Description":"Total Rooms","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":10,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":10,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false}],"Tag":null},{"RowId":14,"Description":"Style","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":33,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":33,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":15,"Description":"Roofing","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":37,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":37,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":16,"Description":"Heating","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":38,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":38,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":17,"Description":"Cooling","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":40,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":40,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},{"FactTypeId":39,"DataType":3,"Format":7,"MaxLength":null,"AreZerosDisplayed":false}],"Tag":null},{"RowId":18,"Description":"Fireplaces","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":43,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":42,"DataType":2,"Format":2,"MaxLength":2,"AreZerosDisplayed":true},{"FactTypeId":41,"DataType":3,"Format":7,"MaxLength":null,"AreZerosDisplayed":false},{"FactTypeId":43,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":19,"Description":"Basement","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":26,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":26,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},{"FactTypeId":24,"DataType":3,"Format":7,"MaxLength":null,"AreZerosDisplayed":false}],"Tag":null},{"RowId":20,"Description":"Foundation","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":36,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":36,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":21,"Description":"Construction","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":34,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":34,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":22,"Description":"Exterior Walls","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":35,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":35,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":23,"Description":"Number of Buildings","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":4,"DataType":2,"Format":2,"MaxLength":2,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":4,"DataType":2,"Format":2,"MaxLength":2,"AreZerosDisplayed":false}],"Tag":null},{"RowId":24,"Description":"Number of Units","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":5,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":true},"FactTypeInfos":[{"FactTypeId":5,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":true}],"Tag":null},{"RowId":25,"Description":"Number of Stories","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":22,"DataType":2,"Format":2,"MaxLength":3,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":22,"DataType":2,"Format":2,"MaxLength":3,"AreZerosDisplayed":false},{"FactTypeId":23,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null}]},"Facts":{"1":{"2":{"Source":2,"LookupDescription":"Single Family Residence","FactTypeId":1,"Value":"1"}},"2":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":2,"Value":"Single Family"}},"4":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":4,"Value":"0"}},"6":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":6,"Value":"6229"}},"7":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":7,"Value":"2170"}},"8":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":8,"Value":"2170"}},"10":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":10,"Value":"8"}},"13":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":13,"Value":"4"}},"15":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":15,"Value":"3"}},"18":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":18,"Value":"2"}},"20":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":20,"Value":"1"}},"27":{"2":{"Source":2,"LookupDescription":"Yes","FactTypeId":27,"Value":"1"}},"28":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":28,"Value":"2"}},"31":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":31,"Value":"Attached Garage"}},"33":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":33,"Value":"Contemporary"}},"35":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":35,"Value":"Other"}},"36":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":36,"Value":"Slab"}},"37":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":37,"Value":"Asphalt"}},"38":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":38,"Value":"Forced air unit"}},"39":{"2":{"Source":2,"LookupDescription":"Yes","FactTypeId":39,"Value":"1"}},"40":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":40,"Value":"Central"}},"44":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":44,"Value":"2004"}},"62":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":62,"Value":"6229 SF"}},"16":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":16,"Value":"2.1"}},"45":{"2":{"Source":2,"LookupDescription":null,"FactTypeId":45,"Value":"14"}},"PropertyType":1,"PropertyTypeText":"Single Family Residence","PropertySubTypeText":"Single Family","LandUse":null,"BuildingCount":null,"UnitCount":null,"LotSizeInSqFt":6229,"LotDimensions":"6229 SF","BuildingAreaInSqFt":2170,"LivingAreaInSqFt":2170,"LivingAreaInSqFtRangeLow":null,"LivingAreaInSqFtRangeHigh":null,"TotalRoomCount":8,"BedroomCount":4,"TotalBathroomCount":3,"FullBathroomCount":2,"PartialBathroomCount":1,"YearBuilt":2004,"Age":14},"FactDropdownLookups":{"7":[{"Value":null,"Description":""},{"Value":1,"Description":"Yes"},{"Value":0,"Description":"No"}],"6":[{"Value":null,"Description":""},{"Value":1,"Description":"Single Family Residence"},{"Value":5,"Description":"Condo/Townhouse/Apt"},{"Value":4,"Description":"Mobile/Manufactured"},{"Value":2,"Description":"Multifamily/Multiplex"},{"Value":7,"Description":"Lot/Land"},{"Value":3,"Description":"Farm/Ranch"},{"Value":6,"Description":"Coop"},{"Value":8,"Description":"Other Residential"}],"10":[{"Value":null,"Description":""},{"Value":"Q1","Description":"Q1"},{"Value":"Q2","Description":"Q2"},{"Value":"Q3","Description":"Q3"},{"Value":"Q4","Description":"Q4"},{"Value":"Q5","Description":"Q5"},{"Value":"Q6","Description":"Q6"}],"9":[{"Value":null,"Description":""},{"Value":"N","Description":"Neutral"},{"Value":"B","Description":"Beneficial"},{"Value":"A","Description":"Adverse"}],"11":[{"Value":null,"Description":""},{"Value":"C1","Description":"C1"},{"Value":"C2","Description":"C2"},{"Value":"C3","Description":"C3"},{"Value":"C4","Description":"C4"},{"Value":"C5","Description":"C5"},{"Value":"C6","Description":"C6"}],"16":[{"Value":null,"Description":""},{"Value":1,"Description":"Fee Simple"},{"Value":2,"Description":"Leasehold"}],"20":[{"Value":null,"Description":""},{"Value":1,"Description":"Airport"},{"Value":2,"Description":"Bus"},{"Value":3,"Description":"Highway"},{"Value":4,"Description":"Taxi"}]},"ShowListingFacts":false,"PropertyFactView":2,"PropertyId":27795318,"OrgId":"","ListingId":"","IsLotSizeConversionDisabled":false,"CustomFactTypes":[]});
});
</script>
<div id="propSumFacts">
<form novalidate="novalidate">
<table id="PropertySummary_FactsTable">
<tbody><tr class="heading">
<th> </th>
<th>Public Facts</th>
<th>Your Changes</th>
</tr>
<tr class="topDottedBorder format-6" factrowid="1">
<td class="title">Property Type</td>
<td class="value" originalvalue="1">
Single Family Residence
</td>
<td class="changed">
<select class="plain fact" facttypeid="1" factsource="0" formatid="6" aria-label="Property Type" name="RprField_2">
<option value="" selected="selected"> </option>
<option value="1">Single Family Residence</option>
<option value="5">Condo/Townhouse/Apt</option>
<option value="4">Mobile/Manufactured</option>
<option value="2">Multifamily/Multiplex</option>
<option value="7">Lot/Land</option>
<option value="3">Farm/Ranch</option>
<option value="6">Coop</option>
<option value="8">Other Residential</option>
</select>
</td>
</tr>
<tr class="topDottedBorder format-1" factrowid="26">
<td class="title">Property Subtype</td>
<td class="value" originalvalue="Single Family">
Single Family
</td>
<td class="changed">
<input type="text" value="" maxlength="100" class="fact" facttypeid="2" factsource="0" formatid="1" originalvalue="" aria-label="Property Subtype" name="RprField_3" />
</td>
</tr>
<tr class="topDottedBorder format-2" factrowid="2">
<td class="title">Bedrooms</td>
<td class="value" originalvalue="4">
4
</td>
<td class="changed">
<input type="text" value="" maxlength="5" class="fact number" isnumeric="true" positivenumberonly="true" nodecimalsallowed="true" facttypeid="13" factsource="0" formatid="2" originalvalue="" aria-label="Bedrooms" name="RprField_4" />
</td>
</tr>
<tr class="topDottedBorder format-2" factrowid="3">
<td class="title">Total Baths</td>
<td class="value" originalvalue="3">
3
</td>
<td class="changed">
<input type="text" value="" maxlength="5" class="fact number" isnumeric="true" positivenumberonly="true" nodecimalsallowed="true" facttypeid="15" factsource="0" formatid="2" originalvalue="" aria-label="Total Baths" name="RprField_5" />
</td>
</tr>
<tr class="topDottedBorder format-2" factrowid="4">
<td class="title">Full Baths</td>
<td class="value" originalvalue="2">
2
</td>
<td class="changed">
<input type="text" value="" maxlength="5" class="fact number" isnumeric="true" positivenumberonly="true" nodecimalsallowed="true" facttypeid="18" factsource="0" formatid="2" originalvalue="" aria-label="Full Baths" name="RprField_6" />
</td>
</tr>
<tr class="topDottedBorder format-2" factrowid="5">
<td class="title">Partial Baths</td>
<td class="value" originalvalue="1">
1
</td>
<td class="changed">
<input type="text" value="" maxlength="5" class="fact number" isnumeric="true" positivenumberonly="true" nodecimalsallowed="true" facttypeid="20" factsource="0" formatid="2" originalvalue="" aria-label="Partial Baths" name="RprField_7" />
</td>
</tr>
<tr class="topDottedBorder format-14" factrowid="6">
<td class="title">Living Area (sq ft)</td>
<td class="value" originalvalue="2170">
2,170
</td>
<td class="changed">
<input type="text" value="" maxlength="6" class="fact number" isnumeric="true" positivenumberonly="true" nodecimalsallowed="true" facttypeid="8" factsource="0" formatid="14" originalvalue="" aria-label="Living Area (sq ft)" name="RprField_8" />
</td>
</tr>
<tr class="topDottedBorder format-18" factrowid="7">
<td class="title">Lot Size</td>
<td class="value" originalvalue="6229">
6,229 sq ft
</td>
<td class="changed">
<input type="text" value="" maxlength="10" class="fact number" isnumeric="true" positivenumberonly="true" nodecimalsallowed="true" lotsizetype="sqft" facttypeid="6" factsource="0" formatid="18" originalvalue="" aria-label="Lot Size" name="RprField_9" /><select class="plain lotSizeType marginLeft5" aria-label="Lot Size Type" name="RprField_10">
<option value="sqft">sq ft</option>
<option value="acres">acres</option>
</select>
</td>
</tr>
<tr class="topDottedBorder format-1" factrowid="27">
<td class="title">Lot Dimensions</td>
<td class="value" originalvalue="6229 SF">
6229 SF
</td>
<td class="changed">
<input type="text" value="" maxlength="100" class="fact" facttypeid="62" factsource="0" formatid="1" originalvalue="" aria-label="Lot Dimensions" name="RprField_11" />
</td>
</tr>
<tr class="topDottedBorder format-7" factrowid="9">
<td class="title">Garage</td>
<td class="value" originalvalue="1">
Yes
</td>
<td class="changed">
<select class="plain fact" facttypeid="27" factsource="0" formatid="7" aria-label="Garage" name="RprField_12">
<option value="" selected="selected"> </option>
<option value="1">Yes</option>
<option value="0">No</option>
</select>
</td>
</tr>
<tr class="topDottedBorder format-2" factrowid="10">
<td class="title">Garage (spaces)</td>
<td class="value" originalvalue="2">
2
</td>
<td class="changed">
<input type="text" value="" maxlength="5" class="fact number" isnumeric="true" positivenumberonly="true" nodecimalsallowed="true" facttypeid="28" factsource="0" formatid="2" originalvalue="" aria-label="Garage (spaces)" name="RprField_13" />
</td>
</tr>
<tr class="topDottedBorder format-3" factrowid="12">
<td class="title">Year Built</td>
<td class="value" originalvalue="2004">
2004
</td>
<td class="changed">
<input type="text" value="" maxlength="4" class="fact number" positivenumberonly="true" nodecimalsallowed="true" facttypeid="44" factsource="0" formatid="3" originalvalue="" aria-label="Year Built" name="RprField_14" />
</td>
</tr>
<tr class="topDottedBorder format-2" factrowid="13">
<td class="title">Total Rooms</td>
<td class="value" originalvalue="8">
8
</td>
<td class="changed">
<input type="text" value="" maxlength="5" class="fact number" isnumeric="true" positivenumberonly="true" nodecimalsallowed="true" facttypeid="10" factsource="0" formatid="2" originalvalue="" aria-label="Total Rooms" name="RprField_15" />
</td>
</tr>
<tr class="topDottedBorder format-1" factrowid="14">
<td class="title">Style</td>
<td class="value" originalvalue="Contemporary">
Contemporary
</td>
<td class="changed">
<input type="text" value="" maxlength="100" class="fact" facttypeid="33" factsource="0" formatid="1" originalvalue="" aria-label="Style" name="RprField_16" />
</td>
</tr>
<tr class="topDottedBorder format-1" factrowid="15">
<td class="title">Roofing</td>
<td class="value" originalvalue="Asphalt">
Asphalt
</td>
<td class="changed">
<input type="text" value="" maxlength="100" class="fact" facttypeid="37" factsource="0" formatid="1" originalvalue="" aria-label="Roofing" name="RprField_17" />
</td>
</tr>
<tr class="topDottedBorder format-1" factrowid="16">
<td class="title">Heating</td>
<td class="value" originalvalue="Forced air unit">
Forced air unit
</td>
<td class="changed">
<input type="text" value="" maxlength="100" class="fact" facttypeid="38" factsource="0" formatid="1" originalvalue="" aria-label="Heating" name="RprField_18" />
</td>
</tr>
<tr class="topDottedBorder format-1" factrowid="17">
<td class="title">Cooling</td>
<td class="value" originalvalue="Central">
Central
</td>
<td class="changed">
<input type="text" value="" maxlength="100" class="fact" facttypeid="40" factsource="0" formatid="1" originalvalue="" aria-label="Cooling" name="RprField_19" />
</td>
</tr>
<tr class="topDottedBorder format-1" factrowid="20">
<td class="title">Foundation</td>
<td class="value" originalvalue="Slab">
Slab
</td>
<td class="changed">
<input type="text" value="" maxlength="100" class="fact" facttypeid="36" factsource="0" formatid="1" originalvalue="" aria-label="Foundation" name="RprField_20" />
</td>
</tr>
<tr class="topDottedBorder format-1" factrowid="22">
<td class="title">Exterior Walls</td>
<td class="value" originalvalue="Other">
Other
</td>
<td class="changed">
<input type="text" value="" maxlength="100" class="fact" facttypeid="35" factsource="0" formatid="1" originalvalue="" aria-label="Exterior Walls" name="RprField_21" />
</td>
</tr>
<tr class="topDottedBorder newFactRow hidden">
<td colspan="2">
<div class="clearfix">
<select class="left" inputmaxlength="25" inputcssclass="newFactComboBoxTxt" id="RprField_1" name="RprField_22"></select>
<a href="#add-selected-fact" class="left rightSeparator marginTop3">Add</a>
<a href="#cancel-new-fact" class="left rightSeparator marginTop3">Cancel</a>
<a href="#edit-custom-fact-types" class="left marginTop3">Edit Custom Fact Types</a>
</div>
</td>
<td class="changed"></td>
</tr>
<tr class="topDottedBorder statusRow">
<td><div class="padTop4"><a href="#add-new-row" class="rightArrow">Add new row</a></div></td>
<td colspan="1">
<div class="clearfix">
<div class="hidden right padTop4 valErrorMsg error">Please fix invalid values...</div>
<div class="hidden right padTop4 saveStatus"></div>
</div>
</td>
<td class="changed">
<div class="clearfix marginTop4 marginBottom5 marginLeft15">
<a href="javascript:;" class="left siteButton saveChangesBtn" id="PropertySummary_Facts_SaveChanges">Save</a>
<a href="javascript:;" class="right textNextToSiteButton clearChangesBtn">Clear</a>
</div>
</td>
</tr>
</tbody></table>
</form>
</div>
<div class="dottedSeparator21"></div>
<div class="rpr-propertyNote" enableautosave="True">
<div class="clearfix">
<div class="left bold marginRight8 padTop2">Notes:</div>
<div class="checkbox left invisible clearfix">
<input type="checkbox" id="RprCheckbox_25" propertyname="IsNotePublic" class="checkbox" checked="checked" /><label for="RprCheckbox_25" class="checkbox">Include in My Reports</label>
</div>
</div>
<textarea propertyname="NoteText" class="marginTop3 hint" style="background-image:url(/hint-text.ashx?Text=Add%20note%20here);" maxlength="1000" rows="6" aria-label="Notes for PropertyFacts"></textarea>
<input type="hidden" value="27795318" propertyname="PropertyId" />
<input type="hidden" value="" propertyname="NoteId" />
<input type="hidden" value="1" propertyname="ContentType" />
<input type="hidden" value="8" propertyname="NoteSection" />
<input type="hidden" value="1" propertyname="Product" />
<input type="hidden" value="" propertyname="BatchId" />
<input type="hidden" value="1" propertyname="AppPropertyMode" />
<div class="clearfix marginTop3">
<div class="left noteStatus"></div>
<div class="right charCount">(1000 characters left)</div>
</div>
</div>
</div>
<div class="boldSeparator25"></div>
</div>
<div class="collapsiblePanel">
<div class="cpHeading cpHeadingGeorgia"><a href="javascript:;" class="cpToggleBtn">Median Estimated Home Value</a></div>
<div class="cpContent estValueChartCont">
<div class="estValueChartLoadingCont"><div class="absLargeSpinner"></div></div>
</div>
<div class="boldSeparator25"></div>
</div>
<div id="interior-details" class="fragment"></div>
<div id="interior-details-panel" class="collapsiblePanel">
<div class="cpHeading cpHeadingGeorgia"><a href="javascript:;" class="cpToggleBtn">Interior Details</a><span class="cpHeadingText2">(from Public Records)</span></div>
<div class="cpContent">
<div class="basicNameValuePairs"><div class="clearfix"><div class="left col1"><div class="item"><span class="name">2nd Floor</span>: 1092 sq ft</div><div class="item"><span class="name">Living Area</span>: 1092 sq ft</div><div class="item"><span class="name">Living Area (2)</span>: 1078 sq ft</div></div><div class="left col2"><div class="item"><span class="name">Garage</span>: 494 sq ft</div><div class="item"><span class="name">Porch - Open</span>: 98 sq ft</div></div></div></div>
</div>
<div class="dottedSeparator25"></div>
</div>
<div id="exterior-details" class="fragment"></div>
<div id="exterior-details-panel" class="collapsiblePanel">
<div class="cpHeading cpHeadingGeorgia"><a href="javascript:;" class="cpToggleBtn">Exterior Details</a><span class="cpHeadingText2">(from Public Records)</span></div>
<div class="cpContent">
<div class="basicNameValuePairs"><div class="clearfix"><div class="left col1"><div class="item"><span class="name">Lot Size - Square Feet</span>: 6229 sq ft</div><div class="item"><span class="name">Lot Size - Acres</span>: 0.143 ac</div></div><div class="left col2"><div class="item"><span class="name">Neighborhood Code</span>: 99411</div></div></div></div>
</div>
<div class="boldSeparator25"></div>
</div>
<div id="location-details" class="fragment"></div>
<div id="location-details-panel" class="collapsiblePanel">
<div class="cpHeading cpHeadingGeorgia"><a href="javascript:;" class="cpToggleBtn">Location Details</a><span class="cpHeadingText2">(from Listing and Other Data Sources)</span></div>
<div class="cpContent">
<div class="tipLabel">No data available...</div>
<div class="basicNameValuePairs adjacent">
<div class="item"><span class="name">Flood Zone: </span><span class="floodZoneInfo">Loading...</span></div>
<div class="item"><span class="name">Walkability Score</span> <span class="lightGray">(out of 5):</span>
<span>Overall: 2.6  |  Amenity: 2.6  |  Leisure: 2.8 <img src="http://static.narrpr.com/1.66.29.2/images/misc/clear.gif" class="infoBtn balloonTip" balloontiptext="This neighborhood or ZIP code is rated for walking access to general points of interest, reflected in the overall score, plus amenities (such as retail stores) and leisure (such as restaurants and parks). Other factors considered in the scores are street types, weather, public transportation and population density." alt="Info" balloontipinitialized="true" /></span></div>
</div>
<div class="dottedSeparator21"></div>
<div class="rpr-propertyNote" enableautosave="True">
<div class="clearfix">
<div class="left bold marginRight8 padTop2">Notes:</div>
<div class="checkbox left invisible clearfix">
<input type="checkbox" id="RprCheckbox_26" propertyname="IsNotePublic" class="checkbox" checked="checked" /><label for="RprCheckbox_26" class="checkbox">Include in My Reports</label>
</div>
</div>
<textarea propertyname="NoteText" class="marginTop3 hint" style="background-image:url(/hint-text.ashx?Text=Add%20note%20here);" maxlength="1000" rows="6" aria-label="Notes for Location"></textarea>
<input type="hidden" value="27795318" propertyname="PropertyId" />
<input type="hidden" value="" propertyname="NoteId" />
<input type="hidden" value="1" propertyname="ContentType" />
<input type="hidden" value="5" propertyname="NoteSection" />
<input type="hidden" value="1" propertyname="Product" />
<input type="hidden" value="" propertyname="BatchId" />
<input type="hidden" value="1" propertyname="AppPropertyMode" />
<div class="clearfix marginTop3">
<div class="left noteStatus"></div>
<div class="right charCount">(1000 characters left)</div>
</div>
</div>
</div>
<div class="boldSeparator25"></div>
</div>
<div id="other-details" class="fragment"></div>
<div id="other-details-panel" class="collapsiblePanel">
<div class="cpHeading cpHeadingGeorgia"><a href="javascript:;" class="cpToggleBtn">Other Details</a><span class="cpHeadingText2">(from Listing and Other Data Sources)</span></div>
<div class="cpContent">
<div class="basicNameValuePairs"><div class="item"><span class="name">Wood Deck</span>: 451</div></div>
</div>
<div class="boldSeparator25"></div>
</div>
<div id="schools" class="fragment"></div>
<div id="schools-panel" class="collapsiblePanel">
<div class="cpHeading cpHeadingGeorgia"><a href="javascript:;" class="cpToggleBtn">Schools</a><span class="cpHeadingText2">(from Listing Data)</span></div>
<div class="cpContent">
<div class="basicNameValuePairs schoolInfo">
<div class="padTop5">Loading...</div>
</div>
</div>
<div class="boldSeparator25"></div>
</div>
<div id="home-energy-consumption" class="fragment"></div>
<div id="home-energy-consumption-panel" class="collapsiblePanel energy-panel">
<div class="cpHeading cpHeadingGeorgia"><a href="javascript:;" class="cpToggleBtn collapsed">Home Energy Consumption</a></div>
<div class="cpContent" style="display:none;">
<div class="energy-loading"><div class="absLargeSpinner"></div></div>
</div>
<div class="boldSeparator25"></div>
</div>
<div id="legal-description" class="fragment"></div>
<div id="legal-description-panel" class="collapsiblePanel">
<div class="cpHeading cpHeadingGeorgia"><a href="javascript:;" class="cpToggleBtn">Legal Description</a><span class="cpHeadingText2">(from Public Records)</span></div>
<div class="cpContent">
<div class="basicNameValuePairs"><div class="item"><span class="name">Parcel Number</span>: 15859-083-0130</div><div class="item"><span class="name">Tax ID</span>: 158590830130</div><div class="item"><span class="name">City/Municipality/Township</span>: SAN ANTONIO</div><div class="item"><span class="name">Census Tract</span>: 480291719.142000</div><div class="item"><span class="name">Carrier Route</span>: C049</div><div class="item"><span class="name">Abbreviated Description</span>: LOT:13 BLK:83 CITY/MUNI/TWP:SAN ANTONIO NCB 15859 BLK 83 LOT 13 HERITAGE HILLS</div></div>
<div class="basicNameValuePairs adjacent">
<div class="item"><span class="name">Plat Map:</span> <span class="platMapInfo">Loading...</span></div>
</div>
<div class="dottedSeparator21"></div>
<div class="rpr-propertyNote" enableautosave="True">
<div class="clearfix">
<div class="left bold marginRight8 padTop2">Notes:</div>
<div class="checkbox left invisible clearfix">
<input type="checkbox" id="RprCheckbox_27" propertyname="IsNotePublic" class="checkbox" checked="checked" /><label for="RprCheckbox_27" class="checkbox">Include in My Reports</label>
</div>
</div>
<textarea propertyname="NoteText" class="marginTop3 hint" style="background-image:url(/hint-text.ashx?Text=Add%20note%20here);" maxlength="1000" rows="6" aria-label="Notes for LegalDescription"></textarea>
<input type="hidden" value="27795318" propertyname="PropertyId" />
<input type="hidden" value="" propertyname="NoteId" />
<input type="hidden" value="1" propertyname="ContentType" />
<input type="hidden" value="9" propertyname="NoteSection" />
<input type="hidden" value="1" propertyname="Product" />
<input type="hidden" value="" propertyname="BatchId" />
<input type="hidden" value="1" propertyname="AppPropertyMode" />
<div class="clearfix marginTop3">
<div class="left noteStatus"></div>
<div class="right charCount">(1000 characters left)</div>
</div>
</div>
</div>
<div class="boldSeparator25"></div>
</div>
<div id="tax-info" class="fragment"></div>
<div id="tax-info-panel" class="collapsiblePanel">
<div class="cpHeading cpHeadingGeorgia"><a href="javascript:;" class="cpToggleBtn">Tax Info</a><span class="cpHeadingText2">(from Public Records)</span></div>
<div class="cpContent">
<div class="basicNameValuePairs"><div class="clearfix"><div class="left col1"><div class="item"><span class="name">Assessment Year</span>: 2016</div><div class="item"><span class="name">Assessed Value - Land</span>: $23,080</div><div class="item"><span class="name">Assessed Value - Improvements</span>: $139,440</div><div class="item"><span class="name">Total Assessed Value</span>: $162,520</div><div class="item"><span class="name">Assessor Market Value Year</span>: 2016</div><div class="item"><span class="name">Assessor Market Value - Land</span>: $23,080</div></div><div class="left col2"><div class="item"><span class="name">Assessor Market Value - Improvements</span>: $139,440</div><div class="item"><span class="name">Total Assessor Market Value</span>: $162,520</div><div class="item"><span class="name">Tax Rate Code Area</span>: 06 08 09 10 11 21</div><div class="item"><span class="name">Tax Year</span>: 2016</div><div class="item"><span class="name">Total Tax Amount</span>: $4,364</div><div class="item"><span class="name">Tax Account ID</span>: 158590830130</div></div></div></div>
<div class="dottedSeparator21"></div>
<div class="rpr-propertyNote" enableautosave="True">
<div class="clearfix">
<div class="left bold marginRight8 padTop2">Notes:</div>
<div class="checkbox left invisible clearfix">
<input type="checkbox" id="RprCheckbox_28" propertyname="IsNotePublic" class="checkbox" checked="checked" /><label for="RprCheckbox_28" class="checkbox">Include in My Reports</label>
</div>
</div>
<textarea propertyname="NoteText" class="marginTop3 hint" style="background-image:url(/hint-text.ashx?Text=Add%20note%20here);" maxlength="1000" rows="6" aria-label="Notes for TaxInfo"></textarea>
<input type="hidden" value="27795318" propertyname="PropertyId" />
<input type="hidden" value="" propertyname="NoteId" />
<input type="hidden" value="1" propertyname="ContentType" />
<input type="hidden" value="7" propertyname="NoteSection" />
<input type="hidden" value="1" propertyname="Product" />
<input type="hidden" value="" propertyname="BatchId" />
<input type="hidden" value="1" propertyname="AppPropertyMode" />
<div class="clearfix marginTop3">
<div class="left noteStatus"></div>
<div class="right charCount">(1000 characters left)</div>
</div>
</div>
</div>
<div class="boldSeparator25"></div>
</div>
<div class="collapsiblePanel">
<div class="cpHeading cpHeadingGeorgia"><a href="javascript:;" class="cpToggleBtn">Deed Records</a><span class="cpHeadingText2">(from Public Records)</span></div>
<div class="cpContent">
<div class="mortgageRecord">
<div class="basicNameValuePairs"><div class="clearfix"><div class="left col1"><div class="item"><span class="name">Document Type</span>: Intrafamily Transfer</div><div class="item"><span class="name">Recording Date</span>: 10/6/2015</div><div class="item"><span class="name">Buyer Name</span>: PATRICK CLAYTON JONES</div><div class="item"><span class="name">Buyer ID</span>: Individual(s)</div></div><div class="left col2"><div class="item"><span class="name">Seller Name</span>: PATRICK CLAYTON JONES, ESTATE OF VIRGINIA MYERS PAPP</div><div class="item"><span class="name">Seller ID</span>: Executor</div><div class="item"><span class="name">Document #</span>: 20150192647</div></div></div></div>
<div class="hidden mrMoreInfo">
<div class="basicNameValuePairs adjacent"><div class="clearfix"><div class="left col1"><div class="item"><span class="name">Book #</span>: 17495</div><div class="item"><span class="name">Page #</span>: 1870</div></div><div class="left col2"><div class="item"><span class="name">Contract Date</span>: 9/30/2015</div><div class="item"><span class="name">Inter-family Transfer</span>: 1</div></div></div></div>
</div>
<div class="marginTop5"><a href="#toggle" class="downArrow mrMoreInfoToggleBtn">Show More</a></div>
</div>
<div class="dottedSeparator21"></div>
<div class="mortgageRecord">
<div class="basicNameValuePairs"><div class="clearfix"><div class="left col1"><div class="item"><span class="name">Document Type</span>: Vendor’s Lien</div><div class="item"><span class="name">Recording Date</span>: 9/27/2004</div><div class="item"><span class="name">Buyer Name</span>: VIRGINIA M PAPP</div></div><div class="left col2"><div class="item"><span class="name">Buyer ID</span>: Single or unmarried woman</div><div class="item"><span class="name">Seller Name</span>:  CHOICE HOMES INC</div><div class="item"><span class="name">Seller ID</span>: Company</div></div></div></div>
<div class="hidden mrMoreInfo">
<div class="basicNameValuePairs adjacent"><div class="clearfix"><div class="left col1"><div class="item"><span class="name">Book #</span>: 10992</div><div class="item"><span class="name">Page #</span>: 1504</div></div><div class="left col2"><div class="item"><span class="name">Contract Date</span>: 9/24/2004</div></div></div></div>
</div>
<div class="marginTop5"><a href="#toggle" class="downArrow mrMoreInfoToggleBtn">Show More</a></div>
</div>
</div>
<div class="boldSeparator25"></div>
</div>
<div class="sumDisclaimer">
<h5>Disclaimer</h5>
<p>All information is not guaranteed and should be independently verified. Any home valuation information has not been prepared, evaluated, or reviewed by a licensed professional appraiser, and should not be relied upon as an appraisal report of the market value of the subject property prepared by a licensed professional appraiser. Listing information is subject to exclusion by the listing broker, and may not include all of the listings available from a participating MLS.</p>
</div>
</div>
<div class="dlRightColumn">
<div class="sidebarMapControlOuter">
<div class="collapsiblePanel">
<div class="cpHeading"><a href="javascript:;" class="cpToggleBtn">MAPS</a></div>
<div class="cpContent">
<div class="mapControlInner">
<div class="movableMapContainer">
<div id="sumMainMap" class=""><div class="outerContainer mapContainer mapContainer-sidebar"><div class="mapContainerOuter"><div class="mapContainerInner" style="position: relative; overflow: hidden;"><div style="height: 100%; width: 100%; position: absolute; top: 0px; left: 0px; background-color: rgb(229, 227, 223);"><div class="gm-style" style="position: absolute; z-index: 0; left: 0px; top: 0px; height: 100%; width: 100%; padding: 0px; border-width: 0px; margin: 0px;"><div tabindex="0" style='position: absolute; z-index: 0; left: 0px; top: 0px; height: 100%; width: 100%; padding: 0px; border-width: 0px; margin: 0px; cursor: url("http://maps.gstatic.com/mapfiles/openhand_8_8.cur") 8 8, default;'><div style="z-index: 1; position: absolute; top: 0px; left: 0px; width: 100%; transform-origin: 0px 0px 0px; transform: matrix(1, 0, 0, 1, 0, 0);"><div style="position: absolute; left: 0px; top: 0px; z-index: 100; width: 100%;"><div style="position: absolute; left: 0px; top: 0px; z-index: 0;"><div aria-hidden="true" style="position: absolute; left: 0px; top: 0px; z-index: 1; visibility: inherit;"><div style="width: 256px; height: 256px; position: absolute; left: -202px; top: 12px;"></div><div style="width: 256px; height: 256px; position: absolute; left: 54px; top: 12px;"></div><div style="width: 256px; height: 256px; position: absolute; left: -202px; top: -244px;"></div><div style="width: 256px; height: 256px; position: absolute; left: -202px; top: 268px;"></div><div style="width: 256px; height: 256px; position: absolute; left: 54px; top: -244px;"></div><div style="width: 256px; height: 256px; position: absolute; left: 54px; top: 268px;"></div></div></div></div><div style="position: absolute; left: 0px; top: 0px; z-index: 101; width: 100%;"></div><div style="position: absolute; left: 0px; top: 0px; z-index: 102; width: 100%;"></div><div style="position: absolute; left: 0px; top: 0px; z-index: 103; width: 100%;"><div style="position: absolute; left: 0px; top: 0px; z-index: -1;"><div aria-hidden="true" style="position: absolute; left: 0px; top: 0px; z-index: 1; visibility: inherit;"><div style="width: 256px; height: 256px; overflow: hidden; position: absolute; left: -202px; top: 12px;"><canvas draggable="false" height="512" width="512" style="user-select: none; position: absolute; left: 0px; top: 0px; height: 256px; width: 256px;"></canvas></div><div style="width: 256px; height: 256px; overflow: hidden; position: absolute; left: 54px; top: 12px;"><canvas draggable="false" height="512" width="512" style="user-select: none; position: absolute; left: 0px; top: 0px; height: 256px; width: 256px;"></canvas></div><div style="width: 256px; height: 256px; overflow: hidden; position: absolute; left: -202px; top: -244px;"></div><div style="width: 256px; height: 256px; overflow: hidden; position: absolute; left: -202px; top: 268px;"><canvas draggable="false" height="512" width="512" style="user-select: none; position: absolute; left: 0px; top: 0px; height: 256px; width: 256px;"></canvas></div><div style="width: 256px; height: 256px; overflow: hidden; position: absolute; left: 54px; top: -244px;"></div><div style="width: 256px; height: 256px; overflow: hidden; position: absolute; left: 54px; top: 268px;"><canvas draggable="false" height="512" width="512" style="user-select: none; position: absolute; left: 0px; top: 0px; height: 256px; width: 256px;"></canvas></div></div></div></div><div style="position: absolute; z-index: 0; left: 0px; top: 0px;"><div style="overflow: hidden; width: 274px; height: 274px;"><img src="http://maps.googleapis.com/maps/api/js/StaticMapService.GetMapImage?1m2&amp;1i15158218&amp;2i27808500&amp;2e1&amp;3u18&amp;4m2&amp;1u274&amp;2u274&amp;5m9&amp;1e0&amp;5sen-US&amp;6sus&amp;8m3&amp;1e33&amp;2e3&amp;8e1&amp;10b1&amp;12b1&amp;token=19287" style="width: 274px; height: 274px;" /></div></div><div style="position: absolute; left: 0px; top: 0px; z-index: 0;"><div aria-hidden="true" style="position: absolute; left: 0px; top: 0px; z-index: 1; visibility: inherit;"><div style="position: absolute; left: -202px; top: 12px; transition: opacity 200ms ease-out;"><div style="position: absolute; left: 0px; top: 0px; z-index: 0;"><img draggable="false" alt="" src="http://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i18!2i59211!3i108627!4i256!2m3!1e0!2sm!3i409106888!3m14!2sen-US!3sUS!5e18!12m1!1e68!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!2zcy50OjMzfHMuZTpsfHAudjpvZmY!4e0!5m1!5f2&amp;token=11951" style="width: 256px; height: 256px; user-select: none; border: 0px; padding: 0px; margin: 0px; max-width: none;" /></div><div style="position: absolute; left: 0px; top: 0px; z-index: 1;"><img draggable="false" alt="" src="http://parcelstream.com/GetMap.aspx?layers=Dmp_License/ParcelTiles&amp;color=cccccc&amp;tileid=023130211103021033" style="width: 256px; height: 256px; user-select: none; border: 0px; padding: 0px; margin: 0px; max-width: none;" /></div></div><div style="position: absolute; left: 54px; top: 12px; transition: opacity 200ms ease-out;"><div style="position: absolute; left: 0px; top: 0px; z-index: 0;"><img draggable="false" alt="" src="http://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i18!2i59212!3i108627!4i256!2m3!1e0!2sm!3i409106888!3m14!2sen-US!3sUS!5e18!12m1!1e68!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!2zcy50OjMzfHMuZTpsfHAudjpvZmY!4e0!5m1!5f2&amp;token=1570" style="width: 256px; height: 256px; user-select: none; border: 0px; padding: 0px; margin: 0px; max-width: none;" /></div><div style="position: absolute; left: 0px; top: 0px; z-index: 1;"><img draggable="false" alt="" src="http://parcelstream.com/GetMap.aspx?layers=Dmp_License/ParcelTiles&amp;color=cccccc&amp;tileid=023130211103021122" style="width: 256px; height: 256px; user-select: none; border: 0px; padding: 0px; margin: 0px; max-width: none;" /></div></div><div style="position: absolute; left: -202px; top: -244px; transition: opacity 200ms ease-out;"><div style="position: absolute; left: 0px; top: 0px; z-index: 0;"><img draggable="false" alt="" src="http://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i18!2i59211!3i108626!4i256!2m3!1e0!2sm!3i409106888!3m14!2sen-US!3sUS!5e18!12m1!1e68!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!2zcy50OjMzfHMuZTpsfHAudjpvZmY!4e0!5m1!5f2&amp;token=7281" style="width: 256px; height: 256px; user-select: none; border: 0px; padding: 0px; margin: 0px; max-width: none;" /></div><div style="position: absolute; left: 0px; top: 0px; z-index: 1;"><img draggable="false" alt="" src="http://parcelstream.com/GetMap.aspx?layers=Dmp_License/ParcelTiles&amp;color=cccccc&amp;tileid=023130211103021031" style="width: 256px; height: 256px; user-select: none; border: 0px; padding: 0px; margin: 0px; max-width: none;" /></div></div><div style="position: absolute; left: -202px; top: 268px; transition: opacity 200ms ease-out;"><div style="position: absolute; left: 0px; top: 0px; z-index: 0;"><img draggable="false" alt="" src="http://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i18!2i59211!3i108628!4i256!2m3!1e0!2sm!3i409106888!3m14!2sen-US!3sUS!5e18!12m1!1e68!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!2zcy50OjMzfHMuZTpsfHAudjpvZmY!4e0!5m1!5f2&amp;token=16621" style="width: 256px; height: 256px; user-select: none; border: 0px; padding: 0px; margin: 0px; max-width: none;" /></div><div style="position: absolute; left: 0px; top: 0px; z-index: 1;"><img draggable="false" alt="" src="http://parcelstream.com/GetMap.aspx?layers=Dmp_License/ParcelTiles&amp;color=cccccc&amp;tileid=023130211103021211" style="width: 256px; height: 256px; user-select: none; border: 0px; padding: 0px; margin: 0px; max-width: none;" /></div></div><div style="position: absolute; left: 54px; top: -244px; transition: opacity 200ms ease-out;"><div style="position: absolute; left: 0px; top: 0px; z-index: 0;"><img draggable="false" alt="" src="http://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i18!2i59212!3i108626!4i256!2m3!1e0!2sm!3i409106888!3m14!2sen-US!3sUS!5e18!12m1!1e68!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!2zcy50OjMzfHMuZTpsfHAudjpvZmY!4e0!5m1!5f2&amp;token=127971" style="width: 256px; height: 256px; user-select: none; border: 0px; padding: 0px; margin: 0px; max-width: none;" /></div><div style="position: absolute; left: 0px; top: 0px; z-index: 1;"><img draggable="false" alt="" src="http://parcelstream.com/GetMap.aspx?layers=Dmp_License/ParcelTiles&amp;color=cccccc&amp;tileid=023130211103021120" style="width: 256px; height: 256px; user-select: none; border: 0px; padding: 0px; margin: 0px; max-width: none;" /></div></div><div style="position: absolute; left: 54px; top: 268px; transition: opacity 200ms ease-out;"><div style="position: absolute; left: 0px; top: 0px; z-index: 0;"><img draggable="false" alt="" src="http://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i18!2i59212!3i108628!4i256!2m3!1e0!2sm!3i409106888!3m14!2sen-US!3sUS!5e18!12m1!1e68!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!2zcy50OjMzfHMuZTpsfHAudjpvZmY!4e0!5m1!5f2&amp;token=6240" style="width: 256px; height: 256px; user-select: none; border: 0px; padding: 0px; margin: 0px; max-width: none;" /></div><div style="position: absolute; left: 0px; top: 0px; z-index: 1;"><img draggable="false" alt="" src="http://parcelstream.com/GetMap.aspx?layers=Dmp_License/ParcelTiles&amp;color=cccccc&amp;tileid=023130211103021300" style="width: 256px; height: 256px; user-select: none; border: 0px; padding: 0px; margin: 0px; max-width: none;" /></div></div></div></div></div><div class="gm-style-pbc" style="z-index: 2; position: absolute; height: 100%; width: 100%; padding: 0px; border-width: 0px; margin: 0px; left: 0px; top: 0px; opacity: 0;"><p class="gm-style-pbt"></p></div><div style="z-index: 3; position: absolute; height: 100%; width: 100%; padding: 0px; border-width: 0px; margin: 0px; left: 0px; top: 0px;"><div style="z-index: 1; position: absolute; height: 100%; width: 100%; padding: 0px; border-width: 0px; margin: 0px; left: 0px; top: 0px;"></div></div><div style="z-index: 4; position: absolute; top: 0px; left: 0px; width: 100%; transform-origin: 0px 0px 0px; transform: matrix(1, 0, 0, 1, 0, 0);"><div style="position: absolute; left: 0px; top: 0px; z-index: 104; width: 100%;"></div><div style="position: absolute; left: 0px; top: 0px; z-index: 105; width: 100%;"></div><div style="position: absolute; left: 0px; top: 0px; z-index: 106; width: 100%;"></div><div style="position: absolute; left: 0px; top: 0px; z-index: 107; width: 100%;"></div></div></div><div style="margin-left: 5px; margin-right: 5px; z-index: 1000000; position: absolute; left: 0px; bottom: 0px;"><a target="_blank" href="https://maps.google.com/maps?ll=29.435427,-98.684246&amp;z=18&amp;t=m&amp;hl=en-US&amp;gl=US&amp;mapclient=apiv3" title="Click to see this area on Google Maps" style="position: static; overflow: visible; float: none; display: inline;"><div style="width: 66px; height: 26px; cursor: pointer;"><img alt="" src="http://maps.gstatic.com/mapfiles/api-3/images/google4_hdpi.png" draggable="false" style="position: absolute; left: 0px; top: 0px; width: 66px; height: 26px; user-select: none; border: 0px; padding: 0px; margin: 0px;" /></div></a></div><div style="background-color: white; padding: 15px 21px; border: 1px solid rgb(171, 171, 171); font-family: Roboto, Arial, sans-serif; color: rgb(34, 34, 34); box-shadow: rgba(0, 0, 0, 0.2) 0px 4px 16px; z-index: 10000002; display: none; width: 220px; height: 148px; position: absolute; left: 5px; top: 47px;"><div style="padding: 0px 0px 10px; font-size: 16px;">Map Data</div><div style="font-size: 13px;">Map data ©2018 Google</div><div style="width: 13px; height: 13px; overflow: hidden; position: absolute; opacity: 0.7; right: 12px; top: 12px; z-index: 10000; cursor: pointer;"><img alt="" src="http://maps.gstatic.com/mapfiles/api-3/images/mapcnt6.png" draggable="false" style="position: absolute; left: -2px; top: -336px; width: 59px; height: 492px; user-select: none; border: 0px; padding: 0px; margin: 0px; max-width: none;" /></div></div><div class="gmnoprint" style="z-index: 1000001; position: absolute; right: 75px; bottom: 0px; width: 121px;"><div draggable="false" class="gm-style-cc" style="user-select: none; height: 14px; line-height: 14px;"><div style="opacity: 0.7; width: 100%; height: 100%; position: absolute;"><div style="width: 1px;"></div><div style="background-color: rgb(245, 245, 245); width: auto; height: 100%; margin-left: 1px;"></div></div><div style="position: relative; padding-right: 6px; padding-left: 6px; font-family: Roboto, Arial, sans-serif; font-size: 10px; color: rgb(68, 68, 68); white-space: nowrap; direction: ltr; text-align: right; vertical-align: middle; display: inline-block;"><a style="color: rgb(68, 68, 68); text-decoration: none; cursor: pointer; display: none;">Map Data</a><span style="">Map data ©2018 Google</span></div></div></div><div class="gmnoscreen" style="position: absolute; right: 0px; bottom: 0px;"><div style="font-family: Roboto, Arial, sans-serif; font-size: 11px; color: rgb(68, 68, 68); direction: ltr; text-align: right; background-color: rgb(245, 245, 245);">Map data ©2018 Google</div></div><div class="gmnoprint gm-style-cc" draggable="false" style="z-index: 1000001; user-select: none; height: 14px; line-height: 14px; position: absolute; right: 0px; bottom: 0px;"><div style="opacity: 0.7; width: 100%; height: 100%; position: absolute;"><div style="width: 1px;"></div><div style="background-color: rgb(245, 245, 245); width: auto; height: 100%; margin-left: 1px;"></div></div><div style="position: relative; padding-right: 6px; padding-left: 6px; font-family: Roboto, Arial, sans-serif; font-size: 10px; color: rgb(68, 68, 68); white-space: nowrap; direction: ltr; text-align: right; vertical-align: middle; display: inline-block;"><a href="https://www.google.com/intl/en-US_US/help/terms_maps.html" target="_blank" style="text-decoration: none; cursor: pointer; color: rgb(68, 68, 68);">Terms of Use</a></div></div><button draggable="false" title="Toggle fullscreen view" aria-label="Toggle fullscreen view" type="button" style="background: none; border: 0px; margin: 10px 14px; padding: 0px; position: absolute; cursor: pointer; user-select: none; width: 25px; height: 25px; overflow: hidden; display: none; top: 0px; right: 0px;"><img alt="" src="http://maps.gstatic.com/mapfiles/api-3/images/sv9.png" draggable="false" class="gm-fullscreen-control" style="position: absolute; left: -52px; top: -86px; width: 164px; height: 175px; user-select: none; border: 0px; padding: 0px; margin: 0px;" /></button><div draggable="false" class="gm-style-cc" style="user-select: none; height: 14px; line-height: 14px; display: none; position: absolute; right: 0px; bottom: 0px;"><div style="opacity: 0.7; width: 100%; height: 100%; position: absolute;"><div style="width: 1px;"></div><div style="background-color: rgb(245, 245, 245); width: auto; height: 100%; margin-left: 1px;"></div></div><div style="position: relative; padding-right: 6px; padding-left: 6px; font-family: Roboto, Arial, sans-serif; font-size: 10px; color: rgb(68, 68, 68); white-space: nowrap; direction: ltr; text-align: right; vertical-align: middle; display: inline-block;"><a target="_new" title="Report errors in the road map or imagery to Google" href="https://www.google.com/maps/@29.435427,-98.684246,18z/data=!10m1!1e1!12b1?source=apiv3&amp;rapsrc=apiv3" style="font-family: Roboto, Arial, sans-serif; font-size: 10px; color: rgb(68, 68, 68); text-decoration: none; position: relative;">Report a map error</a></div></div></div></div></div><div class="mapType clearfix"><div class="right button birdseyeButton"><a href="javascript:;">Overhead</a></div><div class="right button aerialButton"><a href="javascript:;">Aerial</a></div><div class="right button roadButton selected"><a href="javascript:;">Road</a></div><div class="right button grayButton"><a href="javascript:;">Gray</a></div></div><div class="hidden mapPoi mapTypeOn" style="display: none;"><div class="clearfix poiMenu"><a href="javascript:;" class="right poiToggleBtn">POIs</a><a href="javascript:;" class="right padLeft5 padRight15 poiEditBtn poiOnMode">Edit</a><div class="clearfix checkbox left poiEditMode padTop5"><input type="checkbox" id="RprCheckBox_23" value="all" class="checkbox showAllChk" /><label for="RprCheckBox_23" class="checkbox bold">Show All</label></div><div class="left padLeft10 padRight10 poiEditMode lightGray padTop4">|</div><a href="javascript:;" class="left padRight15 poiEditHideBtn poiEditMode padTop5">Hide</a></div><div class="dottedSeparator11 marginLeft10 marginRight10 poiEditMode"></div><div class="poiCat poiEditMode"></div></div><div class="mapZoom"><div class="button zoomInButton"><a href="#zoomin">Zoom in</a></div><div class="button zoomOutButton"><a href="#zoomout">Zoom out</a></div><div class="button rotateCCBtn hidden" style="display: none;"><a href="#rotateCounterClockwise">Rotate counter clockwise</a></div><div class="button rotateCBtn hidden" style="display: none;"><a href="#rotateClockwise">Rotate clockwise</a></div><div class="button recenterButton"><a href="#recenter">Re-center</a></div></div></div><a href="#resize-map" class="mapResizeBtn mapResizeBtn-bigger">Resize Map</a></div><div class="clearfix mapFooter mapFooter-sidebar"><div class="mapCopyright hidden" style="display: block;">© 2018 <a href="http://www.digmap.com/" target="_blank">Digital Map Products</a></div><div class="left footer-legend"><div class="mapLegend"><h3>Map Legend</h3><div class="clearfix"><div class="left clearfix rightDottedBorder legendPt" style="height: 57px;"><h4>Property Type (Icons)</h4><div class="clearfix left item pt pt-1"><div class="left image" style="background-image:url(/map-pin.ashx?PropertyType=1&amp;PropertyStatus=1&amp;v=1.66.29.2);"></div><div class="left text">Single Family</div></div></div><div class="left clearfix legendPs"><h4>Property Status (Colors)</h4><div class="clearfix left item"><div class="left image ps ps-1001"></div><div class="left text ps">Subject</div></div><div class="clearfix left item"><div class="left image ps ps-1"></div><div class="left text ps">Off Market</div></div></div></div><div class="dottedSeparator21 bottomSep"></div></div></div><div class="right footer-heatmaps"><div id="heatmapsPanel" class="invalid">
<h3>Heatmaps</h3>
<p>Heatmaps graphically represent data by using a color scheme to indicate variation in data values.</p>
<h4 class="nomargin">Select an indicator to display:</h4>
<div class="mapChoicesCont">
<select id="HeatmapsPanel_MapChoice_Level1" aria-label="Heatmap Layer 1">
<option value="101" selected="selected" mapid="1">None</option>
<option value="102" mapid="2">Estimated Home Values</option>
<option value="103" mapid="3">12-Month Change in Estimated Value</option>
<option value="104" mapid="4">Estimated Value per Square Foot</option>
<option value="127" mapid="27">Concentration of Distressed Properties</option>
<option value="128" mapid="28">Average Sales Price</option>
<option value="129" mapid="29">Average Listing Price</option>
<option value="130" mapid="30">Pending Sales Concentration</option>
<option value="131" mapid="31">Listing Price vs. Sales Price</option>
<option value="105" mapid="5">Housing Density</option>
<option value="107" mapid="7">Year Built</option>
<option value="108" mapid="8">Flood Zones</option>
</select>
</div>
<div class="legend padTop15 valid"></div>
<div class="clearfix padTop10 valid">
<div class="left copyright" style="display: none;"><a target="_blank" class="externalLink" externallinkinitialized="true"></a></div>
<div class="right"><a href="#about" class="downArrow">About</a></div>
</div>
<div class="aboutText padTop5 hidden" style="display: none;"></div>
<div class="addressTypesCont hidden" style="display: none;">
<div class="dottedSeparator21"></div>
<h4>Geography:</h4>
<select class="addressTypesDdl" mapzoomlevel="">
</select>
</div>
</div></div></div></div>
</div>
</div>
</div>
<div class="boldSeparator25"></div>
</div>
</div>
<script type="text/javascript">
$(document).ready(function ()
{
var dialog = null;
$("#HistoricalListings_CompareBtn").linkCmd(function ()
{
$shared.loadOnDemandResources(Rpr.OnDemandResources.CompareListingsDialog, function ()
{
if (!dialog)
{
dialog = new Rpr.Dialogs.CompareListings({"address":"723 Heritage Way, San Antonio, TX 78245","listings":[{"PropertyId":27795318,"OrgId":"","ListingId":"","ListDate":null,"OrgName":null,"IsListed":false,"IsCurrent":true,"IsPublicRecord":true}]});
}
dialog.show();
});
});
$("#sidebarHistoricalListings.scroll-pane").jScrollPane();
});
</script>
<div class="collapsiblePanel">
<div class="cpHeading"><a href="javascript:;" class="cpToggleBtn">HOW THIS NEIGHBORHOOD COMPARES</a></div>
<div class="cpContent sidebarNeighborhood">
<div class="title marginBottom8">San Antonio, TX 78245</div>
<div><a href="/neighborhoods/tx/san-antonio/78245/70078245-summary.aspx" class="rightArrow">More About this Neighborhood</a></div>
<div class="dottedSeparator21"></div>
<!-- Begin Chart MedianEstimatedHomeValueHorzBarChart (2) -->
<div class="rprChart">
<div class="collapsiblePanel">
<div class="cpHeading"><a href="javascript:;" class="cpToggleBtn">Median Estimated Home Value</a></div>
<div class="cpContent">
<div class="collapsiblePanel aboutPanel">
<div class="cpHeading"><a href="javascript:;" class="cpToggleBtn collapsed" aria-label="About Median Estimated Home Value">About</a></div>
<div class="cpContent" style="display:none;">
<div class="marginBottom5">This chart displays property estimates for an area and a subject property, where one has been selected.  Estimated home values are generated by a valuation model and are not formal appraisals.</div><div class="marginBottom5">Source: Valuation calculations based on public records and MLS sources where licensed</div><div class="marginBottom5">Update Frequency: Monthly</div></div>
</div>
<div id="chart_BaseContent_SiteContent_ctl07_ctl06" class="chartWrapper">
<div class="chartImgContainer marginTop10 clearfix">
<img alt="RPR Chart" src="data:image/png;base64,..." style="width:270px; height:70px; border:0;" title="Median Estimated Home Value" />
</div>
</div></div>
<div class="dottedSeparator25"></div>
</div>
</div>
<!-- End Chart MedianEstimatedHomeValueHorzBarChart -->
<!-- Begin Chart TwelveMonthChangeInMedianEstimatedHomeValueHorzBarChart (3) -->
<div class="rprChart">
<div class="collapsiblePanel">
<div class="cpHeading"><a href="javascript:;" class="cpToggleBtn">12-Month Change in Median Estimated Home Value</a></div>
<div class="cpContent">
<div class="collapsiblePanel aboutPanel">
<div class="cpHeading"><a href="javascript:;" class="cpToggleBtn collapsed" aria-label="About 12-Month Change in Median Estimated Home Value">About</a></div>
<div class="cpContent" style="display:none;">
<div class="marginBottom5">This chart shows the 12-month change in the estimated value of all homes in this area, the county and the state.  Estimated home values are generated by a valuation model and are not formal appraisals.</div><div class="marginBottom5">Source: Valuation calculations based on public records and MLS sources where licensed</div><div class="marginBottom5">Update Frequency: Monthly</div></div>
</div>
<div id="chart_BaseContent_SiteContent_ctl07_ctl07" class="chartWrapper">
<div class="chartImgContainer marginTop10 clearfix">
<img alt="RPR Chart" src="data:image/png;base64,..." style="width:270px; height:70px; border:0;" title="12-Month Change in Median Estimated Home Value" />
</div>
</div></div>
<div class="dottedSeparator25"></div>
</div>
</div>
<!-- End Chart TwelveMonthChangeInMedianEstimatedHomeValueHorzBarChart -->
<!-- Begin Chart MedianSalesPriceHorzBarChart (271) -->
<div class="rprChart">
<div class="collapsiblePanel">
<div class="cpHeading"><a href="javascript:;" class="cpToggleBtn">Median Sales Price</a></div>
<div class="cpContent">
<div class="collapsiblePanel aboutPanel">
<div class="cpHeading"><a href="javascript:;" class="cpToggleBtn collapsed" aria-label="About Median Sales Price">About</a></div>
<div class="cpContent" style="display:none;">
<div class="marginBottom5">This chart displays the median sales price for homes in this area, the county and the state.</div><div class="marginBottom5">Source: Off-market listing sources</div><div class="marginBottom5">Update Frequency: Monthly</div></div>
</div>
<div id="chart_BaseContent_SiteContent_ctl07_ctl08" class="chartWrapper">
<div class="chartImgContainer marginTop10 clearfix">
<img alt="RPR Chart" src="data:image/png;base64,..." style="width:270px; height:70px; border:0;" title="Median Sales Price" />
</div>
</div></div>
<div class="dottedSeparator25"></div>
</div>
</div>
<!-- End Chart MedianSalesPriceHorzBarChart -->
<!-- Begin Chart MedianListingPriceHorzBarChart (4) -->
<div class="rprChart">
<div class="collapsiblePanel">
<div class="cpHeading"><a href="javascript:;" class="cpToggleBtn">Median Listing Price</a></div>
<div class="cpContent">
<div class="collapsiblePanel aboutPanel">
<div class="cpHeading"><a href="javascript:;" class="cpToggleBtn collapsed" aria-label="About Median Listing Price">About</a></div>
<div class="cpContent" style="display:none;">
<div class="marginBottom5">This chart displays the median listing price for homes in this area, the county and the state.</div><div class="marginBottom5">Source: On- and off-market listings sources</div><div class="marginBottom5">Update Frequency: Monthly</div></div>
</div>
<div id="chart_BaseContent_SiteContent_ctl07_ctl09" class="chartWrapper">
<div class="chartImgContainer marginTop10 clearfix">
<img alt="RPR Chart" src="data:image/png;base64,..." style="width:270px; height:70px; border:0;" title="Median Listing Price" />
</div>
</div></div>
<div class="dottedSeparator25"></div>
</div>
</div>
<!-- End Chart MedianListingPriceHorzBarChart -->
<!-- Begin Chart TwelveMonthChangeInMedianListingPriceHorzBarChart (5) -->
<div class="rprChart">
<div class="collapsiblePanel">
<div class="cpHeading"><a href="javascript:;" class="cpToggleBtn">12-Month Change in Median Listing Price</a></div>
<div class="cpContent">
<div class="collapsiblePanel aboutPanel">
<div class="cpHeading"><a href="javascript:;" class="cpToggleBtn collapsed" aria-label="About 12-Month Change in Median Listing Price">About</a></div>
<div class="cpContent" style="display:none;">
<div class="marginBottom5">This chart displays the 12-month change in the median listing price of homes in this area, and compares it to the county and state.</div><div class="marginBottom5">Source: On- and off-market listings sources</div><div class="marginBottom5">Update Frequency: Monthly</div></div>
</div>
<div id="chart_BaseContent_SiteContent_ctl07_ctl10" class="chartWrapper">
<div class="chartImgContainer marginTop10 clearfix">
<img alt="RPR Chart" src="data:image/png;base64,..." style="width:270px; height:70px; border:0;" title="12-Month Change in Median Listing Price" />
</div>
</div></div>
<div class="dottedSeparator25"></div>
</div>
</div>
<!-- End Chart TwelveMonthChangeInMedianListingPriceHorzBarChart -->
<!-- Begin Chart MedianDaysInRprHorzBarChart (21) -->
<div class="rprChart">
<div class="collapsiblePanel">
<div class="cpHeading"><a href="javascript:;" class="cpToggleBtn">Median Days in RPR</a></div>
<div class="cpContent">
<div class="collapsiblePanel aboutPanel">
<div class="cpHeading"><a href="javascript:;" class="cpToggleBtn collapsed" aria-label="About Median Days in RPR">About</a></div>
<div class="cpContent" style="display:none;">
<div class="marginBottom5">This chart shows how long homes are listed on RPR before their status is converted to sold.  The median is calculated for all homes sold in a given month.</div><div class="marginBottom5">Source: On- and off-market listings sources</div><div class="marginBottom5">Update Frequency: Monthly</div></div>
</div>
<div id="chart_BaseContent_SiteContent_ctl07_ctl11" class="chartWrapper">
<div class="chartImgContainer marginTop10 clearfix">
<img alt="RPR Chart" src="data:image/png;base64,..." style="width:270px; height:70px; border:0;" title="Median Days in RPR" />
</div>
</div></div>
<div class="dottedSeparator25"></div>
</div>
</div>
<!-- End Chart MedianDaysInRprHorzBarChart -->
<!-- Begin Chart TwelveMonthChangeInMedianDaysInRprHorzBarChart (6) -->
<div class="rprChart">
<div class="collapsiblePanel">
<div class="cpHeading"><a href="javascript:;" class="cpToggleBtn">12-Month Change in Median Days in RPR</a></div>
<div class="cpContent">
<div class="collapsiblePanel aboutPanel">
<div class="cpHeading"><a href="javascript:;" class="cpToggleBtn collapsed" aria-label="About 12-Month Change in Median Days in RPR">About</a></div>
<div class="cpContent" style="display:none;">
<div class="marginBottom5">This chart displays the percentage change in the length of time homes have been on the market in this area, the county and the state.</div><div class="marginBottom5">Source: On- and off-market listings sources</div><div class="marginBottom5">Update Frequency: Monthly</div></div>
</div>
<div id="chart_BaseContent_SiteContent_ctl07_ctl12" class="chartWrapper">
<div class="chartImgContainer marginTop10 clearfix">
<img alt="RPR Chart" src="data:image/png;base64,..." style="width:270px; height:70px; border:0;" title="12-Month Change in Median Days in RPR" />
</div>
</div></div>
<div class="dottedSeparator25"></div>
</div>
</div>
<!-- End Chart TwelveMonthChangeInMedianDaysInRprHorzBarChart -->
<div class="clearfix"><a href="/neighborhoods/tx/san-antonio/78245/70078245-summary.aspx" class="left siteButton">More About This Neighborhood</a></div>
</div>
<div class="boldSeparator25"></div>
</div>
<script type="text/javascript">
$(document).ready(function () { new Rpr.NearbySchoolsSidebar(); });
</script>
<div class="collapsiblePanel">
<div class="cpHeading"><a href="javascript:;" class="cpToggleBtn">SCHOOLS NEARBY</a></div>
<div class="cpContent">
<div id="schoolsNearby">
<div class="nearbySchool" style="display: block;">
<div><a href="/schools/tx/san-antonio/stevens-high-school/4811053-summary.aspx">Stevens High School</a></div>
<div>Type: Public   Grades Served: 9-12</div>
<div class="clearfix">
<div class="schoolRatingText">School Rating: <strong>4</strong></div>
<div class="ratingStarsContainer">
<div id="BaseContent_SiteContent_ctl09_RepeaterSchools_school_0" class="ratingStars" style="width:68px;"></div>
</div>
</div>
<div class="dottedSeparator21"></div>
</div>
<div class="nearbySchool" style="display: block;">
<div><a href="/schools/tx/san-antonio/murnin-elementary-school/4811093-summary.aspx">Murnin Elementary School</a></div>
<div>Type: Public   Grades Served: PK-5</div>
<div class="clearfix">
<div class="schoolRatingText">School Rating: <strong>7</strong></div>
<div class="ratingStarsContainer">
<div id="BaseContent_SiteContent_ctl09_RepeaterSchools_school_1" class="ratingStars" style="width:119px;"></div>
</div>
</div>
<div class="dottedSeparator21"></div>
</div>
<div class="nearbySchool" style="display: block;">
<div><a href="/schools/tx/san-antonio/cody-elementary-school/4805175-summary.aspx">Cody Elementary School</a></div>
<div>Type: Public   Grades Served: PK-5</div>
<div class="clearfix">
<div class="schoolRatingText">School Rating: <strong>8</strong></div>
<div class="ratingStarsContainer">
<div id="BaseContent_SiteContent_ctl09_RepeaterSchools_school_2" class="ratingStars" style="width:136px;"></div>
</div>
</div>
<div class="dottedSeparator21"></div>
</div>
<div class="nearbySchool" style="display: block;">
<div><a href="/schools/tx/san-antonio/pease-middle-school/4805140-summary.aspx">Pease Middle School</a></div>
<div>Type: Public   Grades Served: 6-8</div>
<div class="clearfix">
<div class="schoolRatingText">School Rating: <strong>3</strong></div>
<div class="ratingStarsContainer">
<div id="BaseContent_SiteContent_ctl09_RepeaterSchools_school_3" class="ratingStars" style="width:51px;"></div>
</div>
</div>
<div class="dottedSeparator21"></div>
</div>
<div class="nearbySchool" style="display: block;">
<div><a href="/schools/tx/san-antonio/lewis-elementary-school/4809086-summary.aspx">Lewis Elementary School</a></div>
<div>Type: Public   Grades Served: PK-5</div>
<div class="clearfix">
<div class="schoolRatingText">School Rating: <strong>9</strong></div>
<div class="ratingStarsContainer">
<div id="BaseContent_SiteContent_ctl09_RepeaterSchools_school_4" class="ratingStars" style="width:153px;"></div>
</div>
</div>
<div class="dottedSeparator21"></div>
</div>
<div class="nearbySchool hidden" style="display: none;">
<div><a href="/schools/tx/san-antonio/alternative-high-school/4819579-summary.aspx">Alternative High School</a></div>
<div>Type: Public   Grades Served: 9-12</div>
<div class="clearfix">
<div class="schoolRatingText">School Rating: <strong>NA</strong></div>
<div class="ratingStarsContainer">
<div id="BaseContent_SiteContent_ctl09_RepeaterSchools_school_5" class="ratingStars" style="width:0px;"></div>
</div>
</div>
<div class="dottedSeparator21"></div>
</div>
<div class="nearbySchool hidden" style="display: none;">
<div><a href="/schools/tx/san-antonio/forester-elementary-school/4812109-summary.aspx">Forester Elementary School</a></div>
<div>Type: Public   Grades Served: PK-5</div>
<div class="clearfix">
<div class="schoolRatingText">School Rating: <strong>7</strong></div>
<div class="ratingStarsContainer">
<div id="BaseContent_SiteContent_ctl09_RepeaterSchools_school_6" class="ratingStars" style="width:119px;"></div>
</div>
</div>
<div class="dottedSeparator21"></div>
</div>
<div class="nearbySchool hidden" style="display: none;">
<div><a href="/schools/tx/san-antonio/hatchett-elementary-school/4810137-summary.aspx">Hatchett Elementary School</a></div>
<div>Type: Public   Grades Served: PK-5</div>
<div class="clearfix">
<div class="schoolRatingText">School Rating: <strong>4</strong></div>
<div class="ratingStarsContainer">
<div id="BaseContent_SiteContent_ctl09_RepeaterSchools_school_7" class="ratingStars" style="width:68px;"></div>
</div>
</div>
<div class="dottedSeparator21"></div>
</div>
<div class="nearbySchool hidden" style="display: none;">
<div><a href="/schools/tx/san-antonio/vale-middle-school/4812048-summary.aspx">Vale Middle School</a></div>
<div>Type: Public   Grades Served: 6-8</div>
<div class="clearfix">
<div class="schoolRatingText">School Rating: <strong>5</strong></div>
<div class="ratingStarsContainer">
<div id="BaseContent_SiteContent_ctl09_RepeaterSchools_school_8" class="ratingStars" style="width:85px;"></div>
</div>
</div>
<div class="dottedSeparator21"></div>
</div>
<div class="nearbySchool hidden" style="display: none;">
<div><a href="/schools/tx/san-antonio/raba-elementary-school/4809087-summary.aspx">Raba Elementary School</a></div>
<div>Type: Public   Grades Served: PK-5</div>
<div class="clearfix">
<div class="schoolRatingText">School Rating: <strong>8</strong></div>
<div class="ratingStarsContainer">
<div id="BaseContent_SiteContent_ctl09_RepeaterSchools_school_9" class="ratingStars" style="width:136px;"></div>
</div>
</div>
<div class="dottedSeparator21"></div>
</div>
<div class="nearbySchool hidden" style="display: none;">
<div><a href="/schools/tx/san-antonio/evers-elementary-school/4805124-summary.aspx">Evers Elementary School</a></div>
<div>Type: Public   Grades Served: PK-5</div>
<div class="clearfix">
<div class="schoolRatingText">School Rating: <strong>8</strong></div>
<div class="ratingStarsContainer">
<div id="BaseContent_SiteContent_ctl09_RepeaterSchools_school_10" class="ratingStars" style="width:136px;"></div>
</div>
</div>
<div class="dottedSeparator21"></div>
</div>
<div class="nearbySchool hidden" style="display: none;">
<div><a href="/schools/tx/san-antonio/jordan-middle-school/4805130-summary.aspx">Jordan Middle School</a></div>
<div>Type: Public   Grades Served: 6-8</div>
<div class="clearfix">
<div class="schoolRatingText">School Rating: <strong>5</strong></div>
<div class="ratingStarsContainer">
<div id="BaseContent_SiteContent_ctl09_RepeaterSchools_school_11" class="ratingStars" style="width:85px;"></div>
</div>
</div>
<div class="dottedSeparator21"></div>
</div>
<div class="nearbySchool hidden" style="display: none;">
<div><a href="/schools/tx/san-antonio/adams-hill-elementary-school/4805133-summary.aspx">Adams Hill Elementary School</a></div>
<div>Type: Public   Grades Served: PK-5</div>
<div class="clearfix">
<div class="schoolRatingText">School Rating: <strong>4</strong></div>
<div class="ratingStarsContainer">
<div id="BaseContent_SiteContent_ctl09_RepeaterSchools_school_12" class="ratingStars" style="width:68px;"></div>
</div>
</div>
<div class="dottedSeparator21"></div>
</div>
<div class="nearbySchool hidden" style="display: none;">
<div><a href="/schools/tx/san-antonio/harmony-science-academy-san-antonio/4811666-summary.aspx">Harmony Science Academy - San Antonio</a></div>
<div>Type: Charter   Grades Served: K-12</div>
<div class="clearfix">
<div class="schoolRatingText">School Rating: <strong>6</strong></div>
<div class="ratingStarsContainer">
<div id="BaseContent_SiteContent_ctl09_RepeaterSchools_school_13" class="ratingStars" style="width:102px;"></div>
</div>
</div>
<div class="dottedSeparator21"></div>
</div>
<div class="nearbySchool hidden" style="display: none;">
<div><a href="/schools/tx/san-antonio/warren-high-school/4809638-summary.aspx">Warren High School</a></div>
<div>Type: Public   Grades Served: 9-12</div>
<div class="clearfix">
<div class="schoolRatingText">School Rating: <strong>5</strong></div>
<div class="ratingStarsContainer">
<div id="BaseContent_SiteContent_ctl09_RepeaterSchools_school_14" class="ratingStars" style="width:85px;"></div>
</div>
</div>
<div class="dottedSeparator21"></div>
</div>
<div class="clearfix">
<a class="right rightArrow" href="#next">Show Next 5</a>
<a class="disabled leftArrow" href="#prev">Show Prev. 5</a>
</div>
</div>
</div>
</div>
</div>
</div>
</div>
</div>
</div>
</div>
<div class="siteFooterContainer">
<div class="siteSection">
<div class="siteFooterColumns clearfix">
<div class="left">
<div class="colLinks">
<div><a href="http://blog.narrpr.com/product/what-is-realtors-property-resource" target="_blank" class="externalLink" id="FooterLink_AboutRpr" externallinkinitialized="true">About RPR</a></div>
<div><a href="/terms-of-use" id="FooterLink_TOU">Terms of Use</a>  |  <a href="/privacy-policy" id="FooterLink_Privacy">Privacy Policy</a></div>
</div>
</div>
<div class="left footerColSep"></div>
<div class="left">
<div class="colLinks">
<div><a href="http://blog.narrpr.com/" target="_blank" class="externalLink" id="FooterLink_Blog" externallinkinitialized="true">Blog</a></div>
<div><a href="http://www.facebook.com/NARRPR" target="_blank" class="externalLink" id="FooterLink_Facebook" externallinkinitialized="true">Facebook</a></div>
</div>
</div>
<div class="left footerColSep"></div>
<div class="left">
<div class="colLinks">
<div><a href="http://learn.narrpr.com/" target="_blank" class="externalLink" id="FooterLink_Help" externallinkinitialized="true">Learning</a></div>
<div><a href="http://support.narrpr.com/" target="_blank" class="externalLink" id="FooterLink_Support" externallinkinitialized="true">Support</a></div>
</div>
</div>
<div class="left footerColSep"></div>
<div class="left realtorCol">
<div class="row1">Find out about<br />becoming a REALTOR<sup>®</sup></div>
<div class="row2"><a href="http://www.realtor.org/membership/how-to-join-nar" target="_blank" class="rightArrow white">More Info</a></div>
</div>
<div class="right liveChatCol">
<div class="nowrap">Need more help? Call us or chat.</div>
<div class="nowrap">(877) 977-7576</div>
<div class="nowrap small">24 hours a day, seven days a week</div>
<a href="#live-chat" class="siteButton liveChatLink shadow2" livechatlinkinitialized="true">Live Chat</a>
</div>
<div class="right footerColSep"></div>
</div>
<div class="siteFooterLegal clearfix">
<a href="http://blog.narrpr.com/" class="left logo externalLink" aria-label="Logo" externallinkinitialized="true">This website is powered by</a>
<div class="left legal">
Copyright © 2018 Realtors Property Resource®, LLC.<span class="buildLabel">Build 1.66.29.2 (Sprint 80)</span><br />
Realtors Property Resource® and RPR are trademarks of Realtors Property Resource®, LLC. All rights reserved.
</div>
</div>
</div>
<div class="coBrandFooter">
<div class="siteSection">
<div class="clearfix">
<div class="left coBrandFooterLogo" style="background:url(http://staticaws.narrpr.com/Images/Orgs/TXSABOR-n/CoBrand.TXSABOR-n.Logo.Footer.2011-04-22-19-38-48.png) no-repeat left center;"></div>
<div class="right coBrandLinks clearfix">
<a href="http://www.sabor.com" target="_blank" class="left">http://www.sabor.com</a>
</div>
</div>
</div>
</div>
</div>
</div>
<script type="text/javascript">
$(document).ready(function ()
{
new Rpr.Pages.Property.Summary({"data":{"IsSaved":false,"Address":{"AddressType":9,"PlaceName":null,"PlaceFormattedName":null,"StreetAddress":"723 Heritage Way","StreetAddressLine2":null,"City":"San Antonio","County":"Bexar County","State":"TX","Zip":"78245","Fips":"48029","Centroid":{"Latitude":29.4354270000,"Longitude":-98.6842460000},"PlaceId":null,"PropertyId":27795318,"SchoolId":null,"SchoolName":null,"UserDisplayName":null,"IsCityCountyEquivalent":false,"IsGeoCoded":true,"IsPlace":false,"IsSchool":false,"IsIdentified":true,"AsString":"723 Heritage Way, San Antonio, TX 78245","AsUnambiguousString":"723 Heritage Way, San Antonio, TX 78245","AsShortString":"723 Heritage Way, San Antonio, TX 78245","AsShortStringWithCounty":"723 Heritage Way, San Antonio, TX 78245","IsEmpty":false,"Tag":null},"PropertyId":27795318,"ListingId":"","OrgId":"","FormattedAddress":"723 Heritage Way\u003cbr /\u003eSan Antonio, TX 78245","YearBuilt":2004,"ListPrice":null,"IsForLease":false,"LeasePrice":null,"LeasePriceType":0,"LeasePeriod":null,"LastSoldDate":"\/Date(1096243200000)\/","LastSoldPrice":null,"PropertyStatusBullets":["Sold Date: 9/27/2004","Public Record"],"DaysInRpr":0,"ThumbnailPhotoUrl":null,"EstimatedValue":168050,"EstimatedValueSource":3,"EstimatedRangeFrom":146204,"EstimatedRangeTo":189896,"CurrentEstimatedValueLastUpdated":"\/Date(1516060800000)\/","BedroomCount":4,"BathroomCount":3,"PropertyStatusAmountPerSqFt":77.442396313364055299539170507,"LivingAreaInSqFt":2170,"LotSizeInSqFt":6229,"PropertyType":1,"PropertyStatus":1,"PropertyStatusAmount":168050,"PropertyStatusDate":"\/Date(1516060800000)\/","PropertyStatusDateLabel":"Estimate Date","PropertyStatusAmountLabel":"Est. Value","PhotoViewerPhotoUrls":[],"PhotoViewerThumbnailPhotoUrls":[],"HistoricalPhotos":null,"IsCustomCentroid":false,"Apn":"15859-083-0130","PropertyTypeText":"Single Family Residence","IsFirstLook":false,"IsHomePathMortgage":false,"IsHomePathRenovation":false,"AuctionVendor":null,"HomePathUrl":null,"ConfidenceScore":4,"ConfidenceScoreTip":"\u0026lt;p\u0026gt;The RVM\u0026amp;reg; estimates displayed on RPR are the product of multiple Realtors Valuation Model\u0026amp;reg; calculations, each of which uses proprietary algorithms and arrives at its own estimate. The \u0026lt;strong\u0026gt;RVM Confidence Score\u0026lt;/strong\u0026gt; is a value between zero and five stars that indicates the level to which each of the multiple models agrees with the other estimated values. High confidence scores indicate that the different models yield similar estimates for this property. Learn more in our Help Desk: \u0026lt;a href=\u0026quot;http://support.narrpr.com/entries/183465-what-is-an-avm-or-rvm-confidence-score\u0026quot;\u0026gt;What is an AVM or RVM Confidence Score?\u0026lt;/a\u0026gt;\u0026lt;/p\u0026gt;","Tag":"/homes/tx/san-antonio/78245/723-heritage-way/27795318-summary.aspx","UnitDetails":[]},"factViewInfo":{"FactView":2,"AnalysisType":null,"AreOnlyFactsWithValuesShown":true,"CanNewFactsBeAdded":true,"CanFactsBeEdited":true,"AreCustomFactsShown":true,"AreCustomFactsExpanded":false,"UseShortDescriptions":false,"IsPrimaryConfirmFactsView":false,"IsPrimaryAdjustmentsView":false,"Rows":[{"RowId":1,"Description":"Property Type","IsAlwaysShown":true,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":1,"DataType":5,"Format":6,"MaxLength":null,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":1,"DataType":5,"Format":6,"MaxLength":null,"AreZerosDisplayed":false}],"Tag":null},{"RowId":26,"Description":"Property Subtype","IsAlwaysShown":true,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":2,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":2,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":2,"Description":"Bedrooms","IsAlwaysShown":true,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":13,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":13,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false}],"Tag":null},{"RowId":3,"Description":"Total Baths","IsAlwaysShown":true,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":15,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":15,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false}],"Tag":null},{"RowId":4,"Description":"Full Baths","IsAlwaysShown":true,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":18,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":18,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false}],"Tag":null},{"RowId":5,"Description":"Partial Baths","IsAlwaysShown":true,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":20,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":20,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false}],"Tag":null},{"RowId":6,"Description":"Living Area (sq ft)","IsAlwaysShown":true,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":8,"DataType":2,"Format":14,"MaxLength":6,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":8,"DataType":2,"Format":14,"MaxLength":6,"AreZerosDisplayed":false},{"FactTypeId":7,"DataType":2,"Format":14,"MaxLength":10,"AreZerosDisplayed":false}],"Tag":null},{"RowId":29,"Description":"Living Area sq ft range (low)","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":63,"DataType":2,"Format":14,"MaxLength":6,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":63,"DataType":2,"Format":14,"MaxLength":6,"AreZerosDisplayed":false}],"Tag":null},{"RowId":30,"Description":"Living Area sq ft range (high)","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":64,"DataType":2,"Format":14,"MaxLength":6,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":64,"DataType":2,"Format":14,"MaxLength":6,"AreZerosDisplayed":false}],"Tag":null},{"RowId":7,"Description":"Lot Size","IsAlwaysShown":true,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":6,"DataType":2,"Format":18,"MaxLength":10,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":6,"DataType":2,"Format":18,"MaxLength":10,"AreZerosDisplayed":false}],"Tag":null},{"RowId":27,"Description":"Lot Dimensions","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":62,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":62,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":28,"Description":"Tenure","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":56,"DataType":5,"Format":16,"MaxLength":null,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":56,"DataType":5,"Format":16,"MaxLength":null,"AreZerosDisplayed":false}],"Tag":null},{"RowId":8,"Description":"Basement (sq ft)","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":25,"DataType":2,"Format":14,"MaxLength":10,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":25,"DataType":2,"Format":14,"MaxLength":10,"AreZerosDisplayed":false}],"Tag":null},{"RowId":9,"Description":"Garage","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":27,"DataType":3,"Format":7,"MaxLength":null,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":27,"DataType":3,"Format":7,"MaxLength":null,"AreZerosDisplayed":false},{"FactTypeId":31,"DataType":1,"Format":1,"MaxLength":20,"AreZerosDisplayed":false},{"FactTypeId":32,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":10,"Description":"Garage (spaces)","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":28,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":true},"FactTypeInfos":[{"FactTypeId":28,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":true}],"Tag":null},{"RowId":11,"Description":"Pool","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":46,"DataType":3,"Format":7,"MaxLength":null,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":46,"DataType":3,"Format":7,"MaxLength":null,"AreZerosDisplayed":false},{"FactTypeId":47,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":12,"Description":"Year Built","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":44,"DataType":2,"Format":3,"MaxLength":4,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":44,"DataType":2,"Format":3,"MaxLength":4,"AreZerosDisplayed":false}],"Tag":null},{"RowId":13,"Description":"Total Rooms","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":10,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":10,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":false}],"Tag":null},{"RowId":14,"Description":"Style","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":33,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":33,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":15,"Description":"Roofing","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":37,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":37,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":16,"Description":"Heating","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":38,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":38,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":17,"Description":"Cooling","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":40,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":40,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},{"FactTypeId":39,"DataType":3,"Format":7,"MaxLength":null,"AreZerosDisplayed":false}],"Tag":null},{"RowId":18,"Description":"Fireplaces","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":43,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":42,"DataType":2,"Format":2,"MaxLength":2,"AreZerosDisplayed":true},{"FactTypeId":41,"DataType":3,"Format":7,"MaxLength":null,"AreZerosDisplayed":false},{"FactTypeId":43,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":19,"Description":"Basement","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":26,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":26,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},{"FactTypeId":24,"DataType":3,"Format":7,"MaxLength":null,"AreZerosDisplayed":false}],"Tag":null},{"RowId":20,"Description":"Foundation","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":36,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":36,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":21,"Description":"Construction","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":34,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":34,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":22,"Description":"Exterior Walls","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":35,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":35,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null},{"RowId":23,"Description":"Number of Buildings","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":4,"DataType":2,"Format":2,"MaxLength":2,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":4,"DataType":2,"Format":2,"MaxLength":2,"AreZerosDisplayed":false}],"Tag":null},{"RowId":24,"Description":"Number of Units","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":5,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":true},"FactTypeInfos":[{"FactTypeId":5,"DataType":2,"Format":2,"MaxLength":5,"AreZerosDisplayed":true}],"Tag":null},{"RowId":25,"Description":"Number of Stories","IsAlwaysShown":false,"IsIndented":false,"IsValueRequired":false,"IsUsedToFindComps":false,"CanBeAdjusted":false,"OverrideFactTypeInfo":{"FactTypeId":22,"DataType":2,"Format":2,"MaxLength":3,"AreZerosDisplayed":false},"FactTypeInfos":[{"FactTypeId":22,"DataType":2,"Format":2,"MaxLength":3,"AreZerosDisplayed":false},{"FactTypeId":23,"DataType":1,"Format":1,"MaxLength":100,"AreZerosDisplayed":false}],"Tag":null}]},"slideshowPaging":{"DisplayCharCount":44,"CurrentPageSize":1,"ItemsCount":0,"CurrentPageIndex":0,"HasItems":false,"FirstPageIndex":0,"LastPageIndex":-1,"PreviousPageIndex":null,"NextPageIndex":1,"CurrentItemsRange":{"LowerBound":0,"UpperBound":0},"PageIndexes":[]}});
$('.rprChart').chart();
});
</script>
<!-- Start of rpr Zendesk Widget script -->
<script>window.setTimeout(function () { /*&lt;![CDATA[*/window.zEmbed||function(e,t){var n,o,d,i,s,a=[],r=document.createElement("iframe");window.zEmbed=function(){a.push(arguments)},window.zE=window.zE||window.zEmbed,r.src="javascript:false",r.title="",r.role="presentation",(r.frameElement||r).style.cssText="display: none",d=document.getElementsByTagName("script"),d=d[d.length-1],d.parentNode.insertBefore(r,d),i=r.contentWindow,s=i.document;try{o=s}catch(e){n=document.domain,r.src='javascript:var d=document.open();d.domain="'+n+'";void(0);',o=s}o.open()._l=function(){var e=this.createElement("script");n&amp;&amp;(this.domain=n),e.id="js-iframe-async",e.src="https://assets.zendesk.com/embeddable_framework/main.js",this.t=+new Date,this.zendeskHost="rpr.zendesk.com",this.zEQueue=a,this.body.appendChild(e)},o.write('&lt;body onload="document._l();"&gt;'),o.close()}(); }, 2000);
/*]]&gt;*/</script>
<!-- End of rpr Zendesk Widget script -->
<script type="text/javascript">var $env = {"IsDebug":false,"IsAdminMode":false,"AppPropertyMode":1,"EnableDebugTools":false,"ConsoleLogLevel":0,"Version":"1.66.29.2","ApplicationRoot":"http://www.narrpr.com","ResourcesBaseUrl":"http://static.narrpr.com/1.66.29.2","ImagesBaseUrl":"http://static.narrpr.com/1.66.29.2/images","IsAuthenticated":true,"UserFullName":"David Cruz Alvarado","ExpirationDate":null,"IsRealtorAssistantUser":false,"AssistantsAboutToExpire":null,"ShouldShowDisallowedAssistantsNotice":false,"ShouldShowInvalidAgentIdNotice":false,"IsMultipleImpersonationAttempted":false,"ReturnUrl":"","SupportPhoneNumber":"(877) 977-7576","SupportHours":"24 hours a day, seven days a week","CurrentYear":2018,"CurrentMonth":1,"CoBrandCode":"TXSABOR-n","IsCommercial":false,"IsAdminPortal":false,"OrgMessagingStatus":1,"IsIE":false,"IsIE6":false,"IsFirefox":false,"IsMobileDevice":false,"BrowserVersion":63,"ClientIP":"70.117.5.29","PagePath":"/pages/property/summary.aspx","PolicyMapPlacePolygonTileUrlMask":"https://api-dl{subdomain}.policymap.com/d/?id=7\u0026ty=tile\u0026t=bnd\u0026tp=b\u0026q={quadkey}\u0026mo={boundarytype}\u0026blw=1\u0026bcc=000000\u0026to={token}","PolicyMapPlacePolygonDataUrlMask":"https://api.policymap.com:443/d/?id=7\u0026ty=data\u0026t=bnd\u0026bt={boundarytype}\u0026lat={latitude}\u0026lon={longitude}\u0026to={token}","AutoSuggestionsEnable":true,"AutoSuggestionsInvokeMinCharCount":3,"AutoSuggestionsInvokeDelay":300,"LiveChatUrl":"https://home-c16.incontact.com/inContact/ChatClient/ChatClientPatron.aspx?poc=159b3265-b2fd-4d19-b427-635b7974504d\u0026bu=4595464","SpatialStreamInfo":{"HostConnectionUrl":"http://parcelstream.com/","Key":"/dc1/_T193/61197ec1-abd8-4ecd-9847-36c58c6d6d8a_M"},"GoogleAnalyticsId":"UA-12360807-2","GoogleMapsClientId":"gme-realtorsproperty"};</script>
<script src="/resources/1.66.29.2/script.ashx/common" type="text/javascript"></script>
<script src="/resources/1.66.29.2/common-dynamic-scripts.ashx?secure=false" type="text/javascript"></script>
<script src="/resources/1.66.29.2/script.ashx/maps" type="text/javascript"></script>
<script src="/resources/1.66.29.2/script.ashx/mapTools" type="text/javascript"></script>
<script src="//parcelstream.com/api/DmpApi.aspx?map=Google&amp;host=parcelstream.com/&amp;v=3" type="text/javascript"></script>
<script src="/resources/1.66.29.2/script.ashx/propertySummaryPage" type="text/javascript"></script>
<script src="/resources/1.66.29.2/script.ashx/propertyMasterPage" type="text/javascript"></script>
<script src="/resources/1.66.29.2/script.ashx/charts" type="text/javascript"></script>
<iframe src="javascript:false" title="" style="display: none;"></iframe><script type="text/javascript">
(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
ga('create', 'UA-12360807-2', 'auto');
ga('require', 'linkid', 'linkid.js');
ga('require', 'displayfeatures');
ga('set', 'dimension1', 'TXSABOR-n');
ga('set', '&amp;uid', 'd6dcd719-f0b9-48c8-9386-6374561aab30');
ga('send', 'pageview');
</script>
<div class="mapBalloon shadow1" style="display: none;"><div class="bHeader clearfix"><div class="left ellipsis bTitle"></div><a href="#close-balloon" class="right">X</a></div><div class="bBody"><div class="bContent"></div></div></div><div><iframe id="launcher" tabindex="0" class="zEWidget-launcher zEWidget-launcher--active" style="border: none; background: transparent; z-index: 999998; transform: translateZ(0px); position: fixed; opacity: 1; left: 0px; bottom: 0px; width: 112px; height: 47px; margin: 10px 20px;"></iframe></div><div><iframe id="webWidget" tabindex="-1" class="zEWidget-webWidget " style="border: none; background: transparent; z-index: 999999; transform: translateZ(0px); position: fixed; opacity: 0; left: 0px; bottom: 0px; width: 357px; margin-left: 15px; margin-right: 15px; height: 15px; transition-property: none; transition-timing-function: unset; top: -9999px;"></iframe></div></body></html>"""

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'lxml')
items = soup.find_all('div', attrs={"class":'item value nowrap'})
items = [i.text for i in items]
values = soup.find_all('td', attrs={"class":"value"})
values = [i.text.strip("\n") for i in value]

# %%
houses = soup.find_all('div', attrs={"class":"left factsSection basicFacts sectionSeparator"})

# %%
for house in houses:
    details = house.find_all('div', attrs={"class":"item"})
    print("Owner:", details[-1].find('span').text)
    print("Price/sq. foot:", details[-2].find('span').text)
# Out:
# Owner: Jones Patrick Clayton
# Price/sq. foot: $77
