# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime

# %%
date = ['Jan 24, 2018', 'Jan 25, 2018', 'Feb 28, 2018']
# date = [datetime.datetime(i) for i in date]
date = ['za', 'b', 'c']
price = [28.14, 29.01, 28.75]
plt.plot(date, price)
plt.show()
