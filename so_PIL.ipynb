# %%
from PIL import Image

# %%
img = Image.new('RGB', (500,500), "white")
pixels = list(img.getdata())
len(pixels)
250000
# Out:
# 250000

# %%
pixels
# Out:
# [(255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
# ...
